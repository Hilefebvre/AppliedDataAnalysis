# %% [markdown]
# In this homework we will extract interesting information from www.topuniversities.com and www.timeshighereducation.com, two platforms that maintain a global ranking of worldwide universities. This ranking is not offered as a downloadable dataset, so we will have to find a way to scrape the information we need!
# You are not allowed to download manually the entire ranking -- rather you have to understand how the server loads it in your browser. For this task, Postman with the Interceptor extension can help you greatly. We recommend that you watch this [brief tutorial](https://www.youtube.com/watch?v=jBjXVrS8nXs&list=PLM-7VG-sgbtD8qBnGeQM5nvlpqB_ktaLZ&autoplay=1) to understand quickly how to use it.

# %%
import requests
import re
import json
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns

# %% [markdown]
# **Obtain the 200 top-ranking** universities in www.topuniversities.com (ranking 2018). In particular, extract the following fields for each university: **name**, **rank**, **country** and **region**, **number of faculty members** (international and total) and **number of students** (international and total). Some information is not available in the main list and you have to find them in the details page. **Store the resulting dataset in a pandas DataFrame** and answer the following questions:

# %% [markdown]
# First step is to get the url for json data from Chrome Inspector Tool or Postman:
# Using Postman, we define the URL `URL_topu_ranking` where we can get the World University Ranking 2018. It is a text file where the informations are stored as JSON.
# We get this JSON object by doing a request (using the `requests` library). All the informations are in the first attribute `data`, that we extract.

# %%
# JSON of topuniversities ranking
#Using Postman, we know the URL of the information we are looking for: ranking of the universities
URL = 'https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051.txt'

# %% [markdown]
# Secondly, we set up a request to get content of the webpage about top unviersities rankings:

# %%
r = requests.get(URL)

# %% [markdown]
# Then we need to convert json data to dict :

# %%
data = r.json()

# %% [markdown]
# We need to transform this JSON into a data frame. So we convert to df from dict and select only the top 200 rows:

# %%
# All the informations are contains into the associted value of the data key
df = pd.DataFrame.from_dict(data.get('data'))
df = df.iloc[0:200]
df.head()
# Out:
#    cc core_id         country  \
# 0  US     410   United States
# 1  US     573   United States
# 2  US     253   United States
# 3  US      94   United States
# 4  GB      95  United Kingdom
#
#                                                guide  \
# 0  <a href="/where-to-study/north-america/united-...
# 1  <a href="/where-to-study/north-america/united-...
# 2  <a href="/where-to-study/north-america/united-...
# 3  <a href="/where-to-study/north-america/united-...
# 4  <a href="/where-to-study/europe/united-kingdom...
#
#                                                 logo     nid rank_display  \
# 0  <img src="https://www.topuniversities.com/site...  294850            1
# 1  <img src="https://www.topuniversities.com/site...  297282            2
# 2  <img src="https://www.topuniversities.com/site...  294270            3
# 3  <img src="https://www.topuniversities.com/site...  294562            4
# 4  <img src="https://www.topuniversities.com/site...  294561            5
#
#           region score stars                                         title  \
# 0  North America   100     6   Massachusetts Institute of Technology (MIT)
# 1  North America  98.7     5                           Stanford University
# 2  North America  98.4     5                            Harvard University
# 3  North America  97.7     5  California Institute of Technology (Caltech)
# 4         Europe  95.6     5                       University of Cambridge
#
#                                                  url
# 0  /universities/massachusetts-institute-technolo...
# 1                  /universities/stanford-university
# 2                   /universities/harvard-university
# 3  /universities/california-institute-technology-...
# 4                 /universities/university-cambridge

# %% [markdown]
# The dataframe above eventually displays the top ranked 200 universities from QS rankings.

# %% [markdown]
# We create a dataframe `df` which will contain the universities and the interesting fields : **name**, **rank**, **country** and **region**, **number of faculty members** (international and total) and **number of students** (international and total)
#
# Note that we treat only the 200 first items of our dataframe containing the complete ranking, as we are interested only in the 200 top-ranking.
#
#
# Few informations are accessible directly at the `URL_topu_ranking`, so in our `data_topu` object. Others informations, such as the number of students of faculty is not available there. Thu, we have to access the page from each specific university toget those informations.
# To do so, we make a new request to the detail page of the specific university, which return an HTML page that we parse using `BeautifulSoup`.
# By looking at the HTML file separatly, we found in which component the informations we looked for are stored in. According to the type of tag (`div`) and the specific class(e.g. `total student`), we can get the value as a string and then convert it.
#
# If the component does not exist, we save the value as `Nan`.

# %%
nb_faculty=[]
nb_faculty_inter=[]
nb_students=[]
nb_students_inter=[]

for url in df['url']:
    p = requests.get('https://www.topuniversities.com'+url).text
    s = BeautifulSoup(p, 'html.parser')
    
    if(s.find("div", {"class": "total faculty"})!=None):
        nb_faculty.append(s.find("div", {"class": "total faculty"}).find("div",{"class": "number"}).text.strip().replace(',',''))
    else:
        nb_faculty.append(np.nan)
    if(s.find("div", {"class": "inter faculty"})!=None):
        nb_faculty_inter.append(s.find("div", {"class": "inter faculty"}).find("div",{"class": "number"}).string.strip().replace(',',''))
    else:
        nb_faculty_inter.append(np.nan)    
    if(s.find("div", {"class": "total student"})!=None):
        nb_students.append(s.find("div", {"class": "total student"}).find("div",{"class": "number"}).text.strip().replace(',',''))
    else:
        nb_students.append(np.nan)
    if(s.find("div", {"class": "total inter"})!=None):
        nb_students_inter.append(s.find("div", {"class": "total inter"}).find("div",{"class": "number"}).string.strip().replace(',',''))
    else:
        nb_students_inter.append(np.nan)

# %% [markdown]
# Add new columns to dataframe with lists created in the previous step in order to correlate these new info to the universities they belong to:

# %%
df['Nb Faculty QS']=nb_faculty
df['Nb Faculty inter QS']=nb_faculty_inter
df['Nb Students QS']=nb_students
df['Nb Students Inter QS']=nb_students_inter

# %%
df.head()
# Out:
#    cc core_id         country  \
# 0  US     410   United States
# 1  US     573   United States
# 2  US     253   United States
# 3  US      94   United States
# 4  GB      95  United Kingdom
#
#                                                guide  \
# 0  <a href="/where-to-study/north-america/united-...
# 1  <a href="/where-to-study/north-america/united-...
# 2  <a href="/where-to-study/north-america/united-...
# 3  <a href="/where-to-study/north-america/united-...
# 4  <a href="/where-to-study/europe/united-kingdom...
#
#                                                 logo     nid rank_display  \
# 0  <img src="https://www.topuniversities.com/site...  294850            1
# 1  <img src="https://www.topuniversities.com/site...  297282            2
# 2  <img src="https://www.topuniversities.com/site...  294270            3
# 3  <img src="https://www.topuniversities.com/site...  294562            4
# 4  <img src="https://www.topuniversities.com/site...  294561            5
#
#           region score stars                                         title  \
# 0  North America   100     6   Massachusetts Institute of Technology (MIT)
# 1  North America  98.7     5                           Stanford University
# 2  North America  98.4     5                            Harvard University
# 3  North America  97.7     5  California Institute of Technology (Caltech)
# 4         Europe  95.6     5                       University of Cambridge
#
#                                                  url Nb Faculty QS  \
# 0  /universities/massachusetts-institute-technolo...          2982
# 1                  /universities/stanford-university          4285
# 2                   /universities/harvard-university          4350
# 3  /universities/california-institute-technology-...           953
# 4                 /universities/university-cambridge          5490
#
#   Nb Faculty inter QS Nb Students QS Nb Students Inter QS
# 0                1679          11067                 3717
# 1                2042          15878                 3611
# 2                1311          22429                 5266
# 3                 350           2255                  647
# 4                2278          18770                 6699

# %% [markdown]
# Let's clean the dataframe deleting columns with no point in the analysis:

# %%
df.drop(['cc','core_id','guide','logo','nid','score','stars','url'], axis=1, inplace=True)

# %%
df.head()
# Out:
#           country rank_display         region  \
# 0   United States            1  North America
# 1   United States            2  North America
# 2   United States            3  North America
# 3   United States            4  North America
# 4  United Kingdom            5         Europe
#
#                                           title Nb Faculty QS  \
# 0   Massachusetts Institute of Technology (MIT)          2982
# 1                           Stanford University          4285
# 2                            Harvard University          4350
# 3  California Institute of Technology (Caltech)           953
# 4                       University of Cambridge          5490
#
#   Nb Faculty inter QS Nb Students QS Nb Students Inter QS
# 0                1679          11067                 3717
# 1                2042          15878                 3611
# 2                1311          22429                 5266
# 3                 350           2255                  647
# 4                2278          18770                 6699

# %% [markdown]
# We convert the new columns that are in string format into numeric type to be able to perform numerical actions on it :

# %%
df['Nb Faculty QS'] = pd.to_numeric(df['Nb Faculty QS'])
df['Nb Faculty inter QS'] = pd.to_numeric(df['Nb Faculty inter QS'])
df['Nb Students QS'] = pd.to_numeric(df['Nb Students QS'])
df['Nb Students Inter QS'] = pd.to_numeric(df['Nb Students Inter QS'])

# %% [markdown]
# We keep the original data frame intact :

# %%
df_original=df

# %% [markdown]
# ## 1. Which are the best universities in term of:
# * ratio between faculty members and students,
# * ratio of international students?

# %% [markdown]
# We define the ratio between faculty members and students as follow:
# $$ ratio_{faculty/student} = \frac{Total\ number\ of\ faculty}{Total\ number\ of\ students} $$
# We define the ratio of international students as follow:
# $$ ratio_{intl\ stud} = \frac{Number\ of\ international\ students}{Total\ number\ of\ students} $$
#
# We add these ratio in two new fields of our dataframe

# %% [markdown]
# Compute ratio: Faculty/Students and InterStudents/Students and store them in separate dataframe columns

# %%
df['ratio Faculty/Students QS']=df['Nb Faculty QS']/df['Nb Students QS']
df['ratio Inter Students/Students QS']=df['Nb Students Inter QS']/df['Nb Students QS']

# %%
df.head()
# Out:
#           country rank_display         region  \
# 0   United States            1  North America
# 1   United States            2  North America
# 2   United States            3  North America
# 3   United States            4  North America
# 4  United Kingdom            5         Europe
#
#                                           title  Nb Faculty QS  \
# 0   Massachusetts Institute of Technology (MIT)         2982.0
# 1                           Stanford University         4285.0
# 2                            Harvard University         4350.0
# 3  California Institute of Technology (Caltech)          953.0
# 4                       University of Cambridge         5490.0
#
#    Nb Faculty inter QS  Nb Students QS  Nb Students Inter QS  \
# 0               1679.0         11067.0                3717.0
# 1               2042.0         15878.0                3611.0
# 2               1311.0         22429.0                5266.0
# 3                350.0          2255.0                 647.0
# 4               2278.0         18770.0                6699.0
#
#    ratio Faculty/Students QS  ratio Inter Students/Students QS
# 0                   0.269450                          0.335863
# 1                   0.269870                          0.227422
# 2                   0.193945                          0.234785
# 3                   0.422616                          0.286918
# 4                   0.292488                          0.356899

# %% [markdown]
# Sort dataframe by ratio Faculty/Students descending values

# %%
df_sorted_a = df.sort_values(['ratio Faculty/Students QS'], ascending=0)
df_sorted_a
# Out:
#             country rank_display         region  \
# 3     United States            4  North America
# 15    United States           16  North America
# 5    United Kingdom            6         Europe
# 4    United Kingdom            5         Europe
# 16    United States           17  North America
# 1     United States            2  North America
# 0     United States            1  North America
# 185   United States          186  North America
# 18    United States           19  North America
# 17    United States           18  North America
# 7    United Kingdom            8         Europe
# 116         Denmark         =116         Europe
# 72          Denmark          =73         Europe
# 28    United States          =28  North America
# 94           Russia          =95         Europe
# 70      South Korea          =71           Asia
# 58           France           59         Europe
# 6    United Kingdom            7         Europe
# 99    United States          100  North America
# 147   United States         =147  North America
# 2     United States            3  North America
# 181         Belgium         =182         Europe
# 21    United States          =21  North America
# 73      Switzerland          =73         Europe
# 75            Japan          =76           Asia
# 156          France          157         Europe
# 141   United States         =142  North America
# 8     United States            9  North America
# 123     Netherlands          124         Europe
# 35            Japan          =36           Asia
# ..              ...          ...            ...
# 161          Taiwan         =161           Asia
# 49        Australia           50        Oceania
# 140         Germany          141         Europe
# 32    United States           33  North America
# 125         Belgium         =125         Europe
# 106         Germany          107         Europe
# 81      New Zealand          =82        Oceania
# 195           Spain         =195         Europe
# 150     New Zealand          151        Oceania
# 149   United States         =149  North America
# 133   United States          134  North America
# 171           India          172           Asia
# 68    United States           69  North America
# 164   United States         =164  North America
# 119         Germany          120         Europe
# 66    United States           67  North America
# 199           Chile          201  Latin America
# 196   United States         =195  North America
# 59        Australia           60        Oceania
# 71          Belgium          =71         Europe
# 175       Australia          176        Oceania
# 69    United States           70  North America
# 152         Belgium          153         Europe
# 151          Canada          152  North America
# 187           Italy         =188         Europe
# 60    United States           61  North America
# 124         Germany         =125         Europe
# 169           Italy          170         Europe
# 184         Austria         =182         Europe
# 51    United States           52  North America
#
#                                                  title  Nb Faculty QS  \
# 3         California Institute of Technology (Caltech)          953.0
# 15                                     Yale University         4940.0
# 5                                 University of Oxford         6750.0
# 4                              University of Cambridge         5490.0
# 16                            Johns Hopkins University         4462.0
# 1                                  Stanford University         4285.0
# 0          Massachusetts Institute of Technology (MIT)         2982.0
# 185                            University of Rochester         2569.0
# 18                          University of Pennsylvania         5499.0
# 17                                 Columbia University         6189.0
# 7                              Imperial College London         3930.0
# 116                    Technical University of Denmark         2117.0
# 72                            University of Copenhagen         7483.0
# 28                             Northwestern University         4231.0
# 94                   Lomonosov Moscow State University         6709.0
# 70   Pohang University of Science And Technology (P...          664.0
# 58                                 Ecole Polytechnique          649.0
# 6                      UCL (University College London)         6345.0
# 99                  Washington University in St. Louis         2699.0
# 147                                   Emory University         2560.0
# 2                                   Harvard University         4350.0
# 181                   Vrije Universiteit Brussel (VUB)         1792.0
# 21                                     Duke University         2938.0
# 73                                University of Zurich         4997.0
# 75                                   Tohoku University         3411.0
# 156                   École Normale Supérieure de Lyon          382.0
# 141                           University of Pittsburgh         4982.0
# 8                                University of Chicago         2449.0
# 123                              Wageningen University         2277.0
# 35                                    Kyoto University         4060.0
# ..                                                 ...            ...
# 161                      National Tsing Hua University         1020.0
# 49                            The University of Sydney         3360.0
# 140                             RWTH Aachen University         3176.0
# 32        University of California, Los Angeles (UCLA)         2859.0
# 125                                   Ghent University         2520.0
# 106             KIT, Karlsruhe Institute of Technology         1827.0
# 81                          The University of Auckland         2047.0
# 195                  Universitat Autònoma de Barcelona         2187.0
# 150                                University of Otago         1266.0
# 149                          Michigan State University         2884.0
# 133     University of California, Santa Barbara (UCSB)         1449.0
# 171        Indian Institute of Technology Delhi (IITD)          466.0
# 68          University of Illinois at Urbana-Champaign         2554.0
# 164                   University of California, Irvine         1926.0
# 119                     Humboldt-Universität zu Berlin         1966.0
# 66                       University of Texas at Austin         2833.0
# 199                               Universidad de Chile         2256.0
# 196                               Texas A&M University         3446.0
# 59                                   Monash University         3204.0
# 71                                           KU Leuven         2515.0
# 175                    University of Technology Sydney         1328.0
# 69                     Georgia Institute of Technology         1133.0
# 152             Université catholique de Louvain (UCL)         1219.0
# 151                             University of Waterloo         1689.0
# 187       Alma Mater Studiorum - University of Bologna         2990.0
# 60                            University of Washington         2484.0
# 124                          Freie Universitaet Berlin         1375.0
# 169                              Politecnico di Milano         1500.0
# 184                    Vienna University of Technology          706.0
# 51                           New York University (NYU)            NaN
#
#      Nb Faculty inter QS  Nb Students QS  Nb Students Inter QS  \
# 3                  350.0          2255.0                 647.0
# 15                1708.0         12402.0                2469.0
# 5                 2964.0         19720.0                7353.0
# 4                 2278.0         18770.0                6699.0
# 16                1061.0         16146.0                4105.0
# 1                 2042.0         15878.0                3611.0
# 0                 1679.0         11067.0                3717.0
# 185                488.0          9636.0                2805.0
# 18                1383.0         20639.0                4250.0
# 17                 913.0         25045.0                8105.0
# 7                 2071.0         16090.0                8746.0
# 116                966.0          8878.0                2098.0
# 72                2336.0         32119.0                3683.0
# 28                1141.0         18675.0                3422.0
# 94                 373.0         30233.0                5098.0
# 70                 113.0          3117.0                 126.0
# 58                 259.0          3126.0                 924.0
# 6                 2554.0         31080.0               14854.0
# 99                 784.0         13474.0                2706.0
# 147                484.0         12852.0                2154.0
# 2                 1311.0         22429.0                5266.0
# 181                515.0          9284.0                1853.0
# 21                 226.0         15320.0                2864.0
# 73                2617.0         26065.0                5036.0
# 75                 264.0         17827.0                1604.0
# 156                 91.0          2020.0                 221.0
# 141                572.0         26393.0                2937.0
# 8                  635.0         13557.0                3379.0
# 123                323.0         12695.0                3613.0
# 35                 293.0         22974.0                1990.0
# ..                   ...             ...                   ...
# 161                119.0         13890.0                1187.0
# 49                1829.0         46678.0               17030.0
# 140                449.0         44517.0                8556.0
# 32                 662.0         40114.0                6887.0
# 125                482.0         35968.0                3766.0
# 106                410.0         26081.0                4809.0
# 81                 645.0         29641.0                8568.0
# 195                230.0         31986.0                3848.0
# 150                759.0         18532.0                3871.0
# 149                653.0         44951.0                7427.0
# 133                267.0         23149.0                2128.0
# 171                  4.0          7477.0                  80.0
# 68                 259.0         42427.0                9483.0
# 164                377.0         32151.0                8538.0
# 119                407.0         33198.0                4805.0
# 66                 108.0         47995.0                4744.0
# 199                127.0         38848.0                2134.0
# 196                206.0         60294.0                4900.0
# 59                1679.0         57433.0               20578.0
# 71                 784.0         45538.0                6926.0
# 175                546.0         24207.0                7769.0
# 69                  75.0         21082.0                4761.0
# 152                406.0         24277.0                4468.0
# 151                473.0         35541.0                8962.0
# 187                153.0         63399.0                4195.0
# 60                 550.0         56973.0                8373.0
# 124                305.0         32912.0                5735.0
# 169                231.0         36277.0                5593.0
# 184                172.0         17479.0                5199.0
# 51                   NaN             NaN                   NaN
#
#      ratio Faculty/Students QS  ratio Inter Students/Students QS
# 3                     0.422616                          0.286918
# 15                    0.398323                          0.199081
# 5                     0.342292                          0.372870
# 4                     0.292488                          0.356899
# 16                    0.276353                          0.254243
# 1                     0.269870                          0.227422
# 0                     0.269450                          0.335863
# 185                   0.266604                          0.291096
# 18                    0.266437                          0.205921
# 17                    0.247115                          0.323617
# 7                     0.244251                          0.543567
# 116                   0.238455                          0.236314
# 72                    0.232977                          0.114667
# 28                    0.226560                          0.183240
# 94                    0.221910                          0.168624
# 70                    0.213025                          0.040423
# 58                    0.207614                          0.295585
# 6                     0.204151                          0.477928
# 99                    0.200312                          0.200831
# 147                   0.199191                          0.167600
# 2                     0.193945                          0.234785
# 181                   0.193020                          0.199591
# 21                    0.191775                          0.186945
# 73                    0.191713                          0.193209
# 75                    0.191339                          0.089976
# 156                   0.189109                          0.109406
# 141                   0.188762                          0.111280
# 8                     0.180645                          0.249244
# 123                   0.179362                          0.284600
# 35                    0.176722                          0.086620
# ..                         ...                               ...
# 161                   0.073434                          0.085457
# 49                    0.071983                          0.364840
# 140                   0.071344                          0.192196
# 32                    0.071272                          0.171686
# 125                   0.070062                          0.104704
# 106                   0.070051                          0.184387
# 81                    0.069060                          0.289059
# 195                   0.068374                          0.120303
# 150                   0.068314                          0.208882
# 149                   0.064159                          0.165224
# 133                   0.062594                          0.091926
# 171                   0.062324                          0.010699
# 68                    0.060198                          0.223513
# 164                   0.059905                          0.265559
# 119                   0.059220                          0.144738
# 66                    0.059027                          0.098844
# 199                   0.058072                          0.054932
# 196                   0.057153                          0.081268
# 59                    0.055787                          0.358296
# 71                    0.055229                          0.152093
# 175                   0.054860                          0.320940
# 69                    0.053743                          0.225832
# 152                   0.050212                          0.184043
# 151                   0.047523                          0.252159
# 187                   0.047162                          0.066168
# 60                    0.043600                          0.146964
# 124                   0.041778                          0.174253
# 169                   0.041349                          0.154175
# 184                   0.040391                          0.297443
# 51                         NaN                               NaN
#
# [200 rows x 10 columns]

# %%
ax = plt.figure()
g = sns.barplot(x = 'title', y = "ratio Faculty/Students QS", data = df_sorted_a[['title','ratio Faculty/Students QS']][0:10])
g.set_xticklabels(labels = df_sorted_a['title'], rotation=90)
ax.suptitle("Top 10 universities ratio faculty member/ student", fontsize=20, fontweight="bold")
plt.show()

# %% [markdown]
# Sort dataframe by ratio InterStudents/Students descending values

# %%
df_sorted_b = df.sort_values(['ratio Inter Students/Students QS'],ascending=0)
df_sorted_b.head()

# %%
ax = plt.figure()
g = sns.barplot(x = 'title', y = "ratio Inter Students/Students QS", data = df_sorted_b[['title','ratio Inter Students/Students QS']][0:10])
g.set_xticklabels(labels = df_sorted_b['title'], rotation=90)
ax.suptitle("Top 10 universities ratio inter/ student", fontsize=20, fontweight="bold")
plt.show()

# %% [markdown]
# The best university in terms of ratio Faculty/Student is California Institute of Technology (Caltech), with a ratio of 0.42. London School of Economics and Political Sciences presents the highest ratio of international students, which is 0.69, followed by **EPFL** with 0.57.

# %% [markdown]
# ## Answer the previous question aggregating the data by country ...

# %% [markdown]
# We want now to group by Country:

# %%
univ_by_country = df_original.groupby(['country'])

# %% [markdown]
# Compute ratio Faculty/Students wrt. countries

# %%
ratio_faculty_students_c = univ_by_country['Nb Faculty QS'].sum()/univ_by_country['Nb Students QS'].sum()

# %%
ratio_faculty_students_c
# Out:
# country
# Argentina         0.134267
# Australia         0.072962
# Austria           0.064890
# Belgium           0.069924
# Brazil            0.081814
# Canada            0.104140
# Chile             0.068579
# China             0.115389
# Denmark           0.177261
# Finland           0.112885
# France            0.113836
# Germany           0.097594
# Hong Kong         0.128948
# India             0.084248
# Ireland           0.081997
# Israel            0.136047
# Italy             0.046487
# Japan             0.152479
# Malaysia          0.153893
# Mexico            0.108779
# Netherlands       0.102651
# New Zealand       0.068773
# Norway            0.114996
# Russia            0.221910
# Saudi Arabia      0.175828
# Singapore         0.161530
# South Africa      0.088450
# South Korea       0.141721
# Spain             0.084096
# Sweden            0.099939
# Switzerland       0.140434
# Taiwan            0.083042
# United Kingdom    0.136962
# United States     0.120811
# dtype: float64

# %% [markdown]
# Sort ratio Faculty/Students Series by descending values

# %%
ratio_faculty_students_c=ratio_faculty_students_c.sort_values(ascending=False)

# %% [markdown]
# Plot Faculty/Students ratio in function of countries

# %%
ax1 = ratio_faculty_students_c.plot(kind='bar', grid=True, figsize=(10, 6), title='Ratio: Faculty staff /Students')
ax1.set_ylabel("Ratio: Faculty staff/Students")
plt.show()

# %% [markdown]
# Result is suprising, Russia's first !

# %% [markdown]
# Compute ratio InterStudents/Students wrt. countries

# %%
ratio_studentsInter_students_c = univ_by_country['Nb Students Inter QS'].sum()/univ_by_country['Nb Students QS'].sum()

# %% [markdown]
# Sort ratio InterStudents/Students Series by descending values

# %%
ratio_studentsInter_students_c=ratio_studentsInter_students_c.sort_values(ascending=False)

# %%
ratio_studentsInter_students_c
# Out:
# country
# Australia         0.352189
# United Kingdom    0.341705
# Hong Kong         0.310751
# Austria           0.309980
# Switzerland       0.302396
# Singapore         0.276537
# Canada            0.260161
# New Zealand       0.258215
# Ireland           0.235299
# Netherlands       0.232980
# Argentina         0.221658
# France            0.194806
# Malaysia          0.194168
# United States     0.173047
# Sweden            0.170716
# South Africa      0.169703
# Russia            0.168624
# Germany           0.164833
# Saudi Arabia      0.163742
# Belgium           0.147853
# Denmark           0.141960
# Norway            0.126776
# Spain             0.124001
# South Korea       0.116177
# China             0.113748
# Italy             0.098726
# Taiwan            0.094152
# Finland           0.088671
# Japan             0.087363
# Israel            0.062549
# Chile             0.047456
# Brazil            0.033072
# Mexico            0.023082
# India             0.010501
# dtype: float64

# %% [markdown]
# Plot InterStudents/Students ratio in function of countries

# %%
ax2 = ratio_studentsInter_students_c.plot(kind='bar', grid=True, figsize=(10, 6), title='Ratio: Students Inter/Students')
ax2.set_ylabel("Ratio: StudentsInter/Students")
plt.show()

# %% [markdown]
# Australia is the country with the higher international student ratio. One may have UK and Australia inverted with the use of "mean".

# %% [markdown]
# ## Answer the previous question aggregating the data by Region ...

# %% [markdown]
# Group original dataframe by region

# %%
univ_by_region = df_original.groupby(['region'])

# %% [markdown]
# Compute Faculty/Students ratio wrt. regions

# %%
ratio_faculty_students_r = univ_by_region['Nb Faculty QS'].sum()/univ_by_region['Nb Students QS'].sum()

# %% [markdown]
# Sort ratio Faculty/Students Series by descending values

# %%
ratio_faculty_students_r=ratio_faculty_students_r.sort_values(ascending=False)

# %% [markdown]
# Plot ratio wrt. regions

# %%
ax3 = ratio_faculty_students_r.plot(kind='bar', grid=True, figsize=(10, 6), title='Ratio: Faculty/Students')
ax3.set_ylabel("Ratio: Faculty/Students")
plt.show()

# %% [markdown]
# Compute InterStudents/Students ration wrt. regions

# %%
ratio_studentsInter_students_r = univ_by_region['Nb Students Inter QS'].sum()/univ_by_region['Nb Students QS'].sum()

# %% [markdown]
# Sort ratio Series by descending values

# %%
ratio_studentsInter_students_r=ratio_studentsInter_students_r.sort_values(ascending=False)

# %% [markdown]
# Plot ratio wrt. regions

# %%
ax4 = ratio_studentsInter_students_r.plot(kind='bar', grid=True, figsize=(10, 6), title='Ratio: Students Inter/Students')
ax4.set_ylabel("Ratio: StudentsInter/Students")
plt.show()

# %% [markdown]
# So through this 4 histograms we notice that:

# %% [markdown]
# - Individual US and UK universities are mainly represented among both ratios.
# - But regarding the whole country, they do not top the chart of facultaf staff/student ratio.
# - We can deduce than in UK and US, levels of unversities meaning their reputation and attractivness are very disparate.
# - Oceania leads for international students but is last in faculty staff. Europe is average in both !
# - Suprisingly, Russia holds the title of country with the better faculty/student ratio.
# - Europe scores are pulled by UK and Switzerland. This result is coherent since UK and Switzerland universities are in top of europe rankings

# %% [markdown]
# ## 2. Obtain the 200 top-ranking universities in www.timeshighereducation.com (ranking 2018). Repeat the analysis of the previous point and discuss briefly what you observed.

# %% [markdown]
# Now we focus on a new ranking set by the Times.

# %%
url_THE=URL_times = "https://www.timeshighereducation.com"

# %% [markdown]
# By the same process as before, we get the direct link of the JSON

# %%
newURL='https://www.timeshighereducation.com/sites/default/files/the_data_rankings/world_university_rankings_2018_limit0_369a9045a203e176392b9fb8f8c1cb2a.json'

# %% [markdown]
# Get the JSON:

# %%
s = requests.get(newURL)
newdata= s.json()

# %% [markdown]
# Get JSON data content:

# %%
newdf = newdata.get('data')

# %%
newdf
# Out:
# [{'aliases': 'University of Oxford',
#   'location': 'United Kingdom',
#   'member_level': '0',
#   'name': 'University of Oxford',
#   'nid': 468,
#   'rank': '1',
#   'rank_order': '10',
#   'record_type': 'master_account',
#   'scores_citations': '99.1',
#   'scores_citations_rank': '15',
#   'scores_industry_income': '63.7',
#   'scores_industry_income_rank': '169',
#   'scores_international_outlook': '95.0',
#   'scores_international_outlook_rank': '24',
#   'scores_overall': '94.3',
#   'scores_overall_rank': '10',
#   'scores_research': '99.5',
#   'scores_research_rank': '1',
#   'scores_teaching': '86.7',
#   'scores_teaching_rank': '5',
#   'stats_female_male_ratio': '46 : 54',
#   'stats_number_students': '20,409',
#   'stats_pc_intl_students': '38%',
#   'stats_student_staff_ratio': '11.2',
#   'subjects_offered': 'Archaeology,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Physics & Astronomy,Psychology',
#   'url': '/world-university-rankings/university-oxford'},
#  {'aliases': 'University of Cambridge',
#   'location': 'United Kingdom',
#   'member_level': '0',
#   'name': 'University of Cambridge',
#   'nid': 470,
#   'rank': '2',
#   'rank_order': '20',
#   'record_type': 'master_account',
#   'scores_citations': '97.5',
#   'scores_citations_rank': '29',
#   'scores_industry_income': '51.5',
#   'scores_industry_income_rank': '260',
#   'scores_international_outlook': '93.0',
#   'scores_international_outlook_rank': '35',
#   'scores_overall': '93.2',
#   'scores_overall_rank': '20',
#   'scores_research': '97.8',
#   'scores_research_rank': '3',
#   'scores_teaching': '87.8',
#   'scores_teaching_rank': '3',
#   'stats_female_male_ratio': '45 : 55',
#   'stats_number_students': '18,389',
#   'stats_pc_intl_students': '35%',
#   'stats_student_staff_ratio': '10.9',
#   'subjects_offered': 'Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Civil Engineering,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,General Engineering,Geography,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Politics & International Studies (incl Development Studies),Psychology,Sociology,Veterinary Science,Physics & Astronomy',
#   'url': '/world-university-rankings/university-cambridge'},
#  {'aliases': 'California Institute of Technology caltech',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'California Institute of Technology',
#   'nid': 128779,
#   'rank': '=3',
#   'rank_order': '30',
#   'record_type': 'private',
#   'scores_citations': '99.5',
#   'scores_citations_rank': '10',
#   'scores_industry_income': '92.6',
#   'scores_industry_income_rank': '51',
#   'scores_international_outlook': '59.7',
#   'scores_international_outlook_rank': '322',
#   'scores_overall': '93.0',
#   'scores_overall_rank': '30',
#   'scores_research': '97.5',
#   'scores_research_rank': '4',
#   'scores_teaching': '90.3',
#   'scores_teaching_rank': '1',
#   'stats_female_male_ratio': '31 : 69',
#   'stats_number_students': '2,209',
#   'stats_pc_intl_students': '27%',
#   'stats_student_staff_ratio': '6.5',
#   'subjects_offered': 'Architecture,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies)',
#   'url': '/world-university-rankings/california-institute-technology'},
#  {'aliases': 'Stanford University',
#   'location': 'United States',
#   'member_level': '11',
#   'name': 'Stanford University',
#   'nid': 467,
#   'rank': '=3',
#   'rank_order': '40',
#   'record_type': 'private',
#   'scores_citations': '99.9',
#   'scores_citations_rank': '4',
#   'scores_industry_income': '60.5',
#   'scores_industry_income_rank': '189',
#   'scores_international_outlook': '77.6',
#   'scores_international_outlook_rank': '162',
#   'scores_overall': '93.0',
#   'scores_overall_rank': '40',
#   'scores_research': '96.7',
#   'scores_research_rank': '5',
#   'scores_teaching': '89.1',
#   'scores_teaching_rank': '2',
#   'stats_female_male_ratio': '42 : 58',
#   'stats_number_students': '15,845',
#   'stats_pc_intl_students': '22%',
#   'stats_student_staff_ratio': '7.5',
#   'subjects_offered': 'Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/stanford-university'},
#  {'aliases': 'Massachusetts Institute of Technology',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'Massachusetts Institute of Technology',
#   'nid': 471,
#   'rank': '5',
#   'rank_order': '50',
#   'record_type': 'private',
#   'scores_citations': '100.0',
#   'scores_citations_rank': '1',
#   'scores_industry_income': '88.4',
#   'scores_industry_income_rank': '63',
#   'scores_international_outlook': '87.6',
#   'scores_international_outlook_rank': '81',
#   'scores_overall': '92.5',
#   'scores_overall_rank': '50',
#   'scores_research': '91.9',
#   'scores_research_rank': '9',
#   'scores_teaching': '87.3',
#   'scores_teaching_rank': '4',
#   'stats_female_male_ratio': '37 : 63',
#   'stats_number_students': '11,177',
#   'stats_pc_intl_students': '34%',
#   'stats_student_staff_ratio': '8.7',
#   'subjects_offered': 'Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/massachusetts-institute-technology'},
#  {'aliases': 'Harvard University',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'Harvard University',
#   'nid': 466,
#   'rank': '6',
#   'rank_order': '60',
#   'record_type': 'private',
#   'scores_citations': '99.7',
#   'scores_citations_rank': '8',
#   'scores_industry_income': '46.4',
#   'scores_industry_income_rank': '330',
#   'scores_international_outlook': '79.7',
#   'scores_international_outlook_rank': '143',
#   'scores_overall': '91.8',
#   'scores_overall_rank': '60',
#   'scores_research': '98.4',
#   'scores_research_rank': '2',
#   'scores_teaching': '84.2',
#   'scores_teaching_rank': '9',
#   'stats_female_male_ratio': None,
#   'stats_number_students': '20,326',
#   'stats_pc_intl_students': '26%',
#   'stats_student_staff_ratio': '8.9',
#   'subjects_offered': 'Agriculture & Forestry,Archaeology,Art, Performing Arts & Design,Biological Sciences,Chemical Engineering,Chemistry,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/harvard-university'},
#  {'aliases': 'Princeton University',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'Princeton University',
#   'nid': 469,
#   'rank': '7',
#   'rank_order': '70',
#   'record_type': 'private',
#   'scores_citations': '99.6',
#   'scores_citations_rank': '9',
#   'scores_industry_income': '58.0',
#   'scores_industry_income_rank': '204',
#   'scores_international_outlook': '78.7',
#   'scores_international_outlook_rank': '152',
#   'scores_overall': '91.1',
#   'scores_overall_rank': '70',
#   'scores_research': '93.9',
#   'scores_research_rank': '6',
#   'scores_teaching': '85.7',
#   'scores_teaching_rank': '7',
#   'stats_female_male_ratio': '45 : 55',
#   'stats_number_students': '7,955',
#   'stats_pc_intl_students': '24%',
#   'stats_student_staff_ratio': '8.3',
#   'subjects_offered': 'Architecture,Art, Performing Arts & Design,Biological Sciences,Chemical Engineering,Chemistry,Civil Engineering,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/princeton-university'},
#  {'aliases': 'Imperial College London',
#   'location': 'United Kingdom',
#   'member_level': '0',
#   'name': 'Imperial College London',
#   'nid': 472,
#   'rank': '8',
#   'rank_order': '80',
#   'record_type': 'master_account',
#   'scores_citations': '96.7',
#   'scores_citations_rank': '40',
#   'scores_industry_income': '71.6',
#   'scores_industry_income_rank': '120',
#   'scores_international_outlook': '96.6',
#   'scores_international_outlook_rank': '13',
#   'scores_overall': '89.2',
#   'scores_overall_rank': '80',
#   'scores_research': '88.7',
#   'scores_research_rank': '12',
#   'scores_teaching': '81.7',
#   'scores_teaching_rank': '13',
#   'stats_female_male_ratio': '37 : 63',
#   'stats_number_students': '15,857',
#   'stats_pc_intl_students': '55%',
#   'stats_student_staff_ratio': '11.4',
#   'subjects_offered': 'Biological Sciences,Chemical Engineering,Chemistry,Civil Engineering,Computer Science,Education,Electrical & Electronic Engineering,General Engineering,Geology, Environmental, Earth & Marine Sciences,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Physics & Astronomy',
#   'url': '/world-university-rankings/imperial-college-london'},
#  {'aliases': 'University of Chicago',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'University of Chicago',
#   'nid': 473,
#   'rank': '9',
#   'rank_order': '90',
#   'record_type': 'private',
#   'scores_citations': '99.4',
#   'scores_citations_rank': '12',
#   'scores_industry_income': '39.8',
#   'scores_industry_income_rank': '487',
#   'scores_international_outlook': '69.6',
#   'scores_international_outlook_rank': '231',
#   'scores_overall': '88.6',
#   'scores_overall_rank': '90',
#   'scores_research': '90.1',
#   'scores_research_rank': '10',
#   'scores_teaching': '85.3',
#   'scores_teaching_rank': '8',
#   'stats_female_male_ratio': '44 : 56',
#   'stats_number_students': '13,525',
#   'stats_pc_intl_students': '25%',
#   'stats_student_staff_ratio': '6.2',
#   'subjects_offered': 'Archaeology,Art, Performing Arts & Design,Biological Sciences,Chemistry,Computer Science,Economics & Econometrics,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/university-chicago'},
#  {'aliases': 'ETH Zurich – Swiss Federal Institute of Technology Zurich',
#   'location': 'Switzerland',
#   'member_level': '0',
#   'name': 'ETH Zurich – Swiss Federal Institute of Technology Zurich',
#   'nid': 479,
#   'rank': '=10',
#   'rank_order': '100',
#   'record_type': 'master_account',
#   'scores_citations': '94.3',
#   'scores_citations_rank': '60',
#   'scores_industry_income': '60.3',
#   'scores_industry_income_rank': '190',
#   'scores_international_outlook': '98.1',
#   'scores_international_outlook_rank': '8',
#   'scores_overall': '87.7',
#   'scores_overall_rank': '100',
#   'scores_research': '92.0',
#   'scores_research_rank': '8',
#   'scores_teaching': '76.4',
#   'scores_teaching_rank': '21',
#   'stats_female_male_ratio': '31 : 69',
#   'stats_number_students': '19,233',
#   'stats_pc_intl_students': '38%',
#   'stats_student_staff_ratio': '14.6',
#   'subjects_offered': 'Agriculture & Forestry,Architecture,Biological Sciences,Chemistry,Civil Engineering,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geology, Environmental, Earth & Marine Sciences,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Chemical Engineering,Medicine & Dentistry,Business & Management,Accounting & Finance',
#   'url': '/world-university-rankings/eth-zurich-swiss-federal-institute-technology-zurich'},
#  {'aliases': 'University of Pennsylvania',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'University of Pennsylvania',
#   'nid': 480,
#   'rank': '=10',
#   'rank_order': '110',
#   'record_type': 'private',
#   'scores_citations': '98.5',
#   'scores_citations_rank': '22',
#   'scores_industry_income': '56.9',
#   'scores_industry_income_rank': '213',
#   'scores_international_outlook': '61.3',
#   'scores_international_outlook_rank': '300',
#   'scores_overall': '87.7',
#   'scores_overall_rank': '110',
#   'scores_research': '90.1',
#   'scores_research_rank': '11',
#   'scores_teaching': '83.7',
#   'scores_teaching_rank': '10',
#   'stats_female_male_ratio': '50 : 50',
#   'stats_number_students': '20,361',
#   'stats_pc_intl_students': '20%',
#   'stats_student_staff_ratio': '6.5',
#   'subjects_offered': 'Accounting & Finance,Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Communication & Media Studies,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/university-pennsylvania'},
#  {'aliases': 'Yale University',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'Yale University',
#   'nid': 475,
#   'rank': '12',
#   'rank_order': '120',
#   'record_type': 'private',
#   'scores_citations': '98.4',
#   'scores_citations_rank': '24',
#   'scores_industry_income': '45.1',
#   'scores_industry_income_rank': '361',
#   'scores_international_outlook': '64.6',
#   'scores_international_outlook_rank': '272',
#   'scores_overall': '87.6',
#   'scores_overall_rank': '120',
#   'scores_research': '87.0',
#   'scores_research_rank': '17',
#   'scores_teaching': '86.7',
#   'scores_teaching_rank': '6',
#   'stats_female_male_ratio': '49 : 51',
#   'stats_number_students': '12,155',
#   'stats_pc_intl_students': '21%',
#   'stats_student_staff_ratio': '4.3',
#   'subjects_offered': 'Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Chemical Engineering,Chemistry,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/yale-university'},
#  {'aliases': 'Johns Hopkins University',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'Johns Hopkins University',
#   'nid': 478,
#   'rank': '13',
#   'rank_order': '130',
#   'record_type': 'private',
#   'scores_citations': '98.4',
#   'scores_citations_rank': '23',
#   'scores_industry_income': '95.8',
#   'scores_industry_income_rank': '41',
#   'scores_international_outlook': '70.6',
#   'scores_international_outlook_rank': '219',
#   'scores_overall': '86.5',
#   'scores_overall_rank': '130',
#   'scores_research': '88.1',
#   'scores_research_rank': '16',
#   'scores_teaching': '76.1',
#   'scores_teaching_rank': '23',
#   'stats_female_male_ratio': '52 : 48',
#   'stats_number_students': '15,498',
#   'stats_pc_intl_students': '24%',
#   'stats_student_staff_ratio': '4.3',
#   'subjects_offered': 'Agriculture & Forestry,Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/johns-hopkins-university'},
#  {'aliases': 'Columbia University',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'Columbia University',
#   'nid': 476,
#   'rank': '14',
#   'rank_order': '140',
#   'record_type': 'private',
#   'scores_citations': '98.8',
#   'scores_citations_rank': '19',
#   'scores_industry_income': '41.3',
#   'scores_industry_income_rank': '438',
#   'scores_international_outlook': '76.6',
#   'scores_international_outlook_rank': '177',
#   'scores_overall': '86.0',
#   'scores_overall_rank': '140',
#   'scores_research': '83.3',
#   'scores_research_rank': '26',
#   'scores_teaching': '82.2',
#   'scores_teaching_rank': '12',
#   'stats_female_male_ratio': None,
#   'stats_number_students': '26,587',
#   'stats_pc_intl_students': '32%',
#   'stats_student_staff_ratio': '6.1',
#   'subjects_offered': 'Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/columbia-university'},
#  {'aliases': 'University of California, Los Angeles',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'University of California, Los Angeles',
#   'nid': 477,
#   'rank': '15',
#   'rank_order': '150',
#   'record_type': 'public',
#   'scores_citations': '97.9',
#   'scores_citations_rank': '27',
#   'scores_industry_income': '48.6',
#   'scores_industry_income_rank': '298',
#   'scores_international_outlook': '59.5',
#   'scores_international_outlook_rank': '326',
#   'scores_overall': '85.7',
#   'scores_overall_rank': '150',
#   'scores_research': '88.1',
#   'scores_research_rank': '15',
#   'scores_teaching': '80.7',
#   'scores_teaching_rank': '14',
#   'stats_female_male_ratio': '53 : 47',
#   'stats_number_students': '39,279',
#   'stats_pc_intl_students': '17%',
#   'stats_student_staff_ratio': '9.6',
#   'subjects_offered': 'Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/university-california-los-angeles'},
#  {'aliases': 'University College London ucl',
#   'location': 'United Kingdom',
#   'member_level': '0',
#   'name': 'University College London',
#   'nid': 481,
#   'rank': '16',
#   'rank_order': '160',
#   'record_type': 'master_account',
#   'scores_citations': '94.6',
#   'scores_citations_rank': '56',
#   'scores_industry_income': '41.2',
#   'scores_industry_income_rank': '441',
#   'scores_international_outlook': '94.6',
#   'scores_international_outlook_rank': '25',
#   'scores_overall': '85.3',
#   'scores_overall_rank': '160',
#   'scores_research': '88.2',
#   'scores_research_rank': '13',
#   'scores_teaching': '74.4',
#   'scores_teaching_rank': '25',
#   'stats_female_male_ratio': '56 : 44',
#   'stats_number_students': '30,304',
#   'stats_pc_intl_students': '49%',
#   'stats_student_staff_ratio': '10.5',
#   'subjects_offered': 'Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Other Health,Physics & Astronomy,Psychology',
#   'url': '/world-university-rankings/university-college-london'},
#  {'aliases': 'Duke University',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'Duke University',
#   'nid': 487,
#   'rank': '17',
#   'rank_order': '170',
#   'record_type': 'private',
#   'scores_citations': '98.3',
#   'scores_citations_rank': '25',
#   'scores_industry_income': '100.0',
#   'scores_industry_income_rank': '1',
#   'scores_international_outlook': '62.5',
#   'scores_international_outlook_rank': '292',
#   'scores_overall': '85.1',
#   'scores_overall_rank': '170',
#   'scores_research': '80.6',
#   'scores_research_rank': '27',
#   'scores_teaching': '80.7',
#   'scores_teaching_rank': '15',
#   'stats_female_male_ratio': '49 : 51',
#   'stats_number_students': '15,256',
#   'stats_pc_intl_students': '22%',
#   'stats_student_staff_ratio': '4.5',
#   'subjects_offered': 'Art, Performing Arts & Design,Biological Sciences,Chemical Engineering,Chemistry,Civil Engineering,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/duke-university'},
#  {'aliases': 'University of California, Berkeley',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'University of California, Berkeley',
#   'nid': 474,
#   'rank': '18',
#   'rank_order': '180',
#   'record_type': 'public',
#   'scores_citations': '99.8',
#   'scores_citations_rank': '5',
#   'scores_industry_income': '37.5',
#   'scores_industry_income_rank': '586',
#   'scores_international_outlook': '64.5',
#   'scores_international_outlook_rank': '273',
#   'scores_overall': '84.3',
#   'scores_overall_rank': '180',
#   'scores_research': '84.5',
#   'scores_research_rank': '24',
#   'scores_teaching': '77.4',
#   'scores_teaching_rank': '18',
#   'stats_female_male_ratio': '52 : 48',
#   'stats_number_students': '36,182',
#   'stats_pc_intl_students': '17%',
#   'stats_student_staff_ratio': '13.1',
#   'subjects_offered': 'Agriculture & Forestry,Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/university-california-berkeley'},
#  {'aliases': 'Cornell University',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'Cornell University',
#   'nid': 484,
#   'rank': '19',
#   'rank_order': '190',
#   'record_type': 'private',
#   'scores_citations': '97.6',
#   'scores_citations_rank': '28',
#   'scores_industry_income': '34.6',
#   'scores_industry_income_rank': '749',
#   'scores_international_outlook': '69.2',
#   'scores_international_outlook_rank': '233',
#   'scores_overall': '84.2',
#   'scores_overall_rank': '190',
#   'scores_research': '86.6',
#   'scores_research_rank': '19',
#   'scores_teaching': '76.2',
#   'scores_teaching_rank': '22',
#   'stats_female_male_ratio': '49 : 51',
#   'stats_number_students': '21,850',
#   'stats_pc_intl_students': '24%',
#   'stats_student_staff_ratio': '9.8',
#   'subjects_offered': 'Agriculture & Forestry,Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology,Veterinary Science',
#   'url': '/world-university-rankings/cornell-university'},
#  {'aliases': 'Northwestern University',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'Northwestern University',
#   'nid': 490,
#   'rank': '20',
#   'rank_order': '200',
#   'record_type': 'private',
#   'scores_citations': '96.9',
#   'scores_citations_rank': '36',
#   'scores_industry_income': '78.2',
#   'scores_industry_income_rank': '99',
#   'scores_international_outlook': '59.2',
#   'scores_international_outlook_rank': '330',
#   'scores_overall': '83.3',
#   'scores_overall_rank': '200',
#   'scores_research': '86.7',
#   'scores_research_rank': '18',
#   'scores_teaching': '72.6',
#   'scores_teaching_rank': '28',
#   'stats_female_male_ratio': '48 : 52',
#   'stats_number_students': '17,466',
#   'stats_pc_intl_students': '18%',
#   'stats_student_staff_ratio': '12.8',
#   'subjects_offered': 'Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/northwestern-university'},
#  {'aliases': 'University of Michigan',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'University of Michigan',
#   'nid': 482,
#   'rank': '21',
#   'rank_order': '210',
#   'record_type': 'public',
#   'scores_citations': '95.7',
#   'scores_citations_rank': '47',
#   'scores_industry_income': '46.2',
#   'scores_industry_income_rank': '333',
#   'scores_international_outlook': '55.8',
#   'scores_international_outlook_rank': '367',
#   'scores_overall': '83.1',
#   'scores_overall_rank': '210',
#   'scores_research': '86.3',
#   'scores_research_rank': '20',
#   'scores_teaching': '77.2',
#   'scores_teaching_rank': '20',
#   'stats_female_male_ratio': '48 : 52',
#   'stats_number_students': '41,818',
#   'stats_pc_intl_students': '16%',
#   'stats_student_staff_ratio': '8.6',
#   'subjects_offered': 'Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology,Sport Science',
#   'url': '/world-university-rankings/university-michigan'},
#  {'aliases': 'National University of Singapore nus',
#   'location': 'Singapore',
#   'member_level': '6',
#   'name': 'National University of Singapore',
#   'nid': 504,
#   'rank': '=22',
#   'rank_order': '220',
#   'record_type': 'master_account',
#   'scores_citations': '81.3',
#   'scores_citations_rank': '193',
#   'scores_industry_income': '61.9',
#   'scores_industry_income_rank': '181',
#   'scores_international_outlook': '95.8',
#   'scores_international_outlook_rank': '20',
#   'scores_overall': '82.8',
#   'scores_overall_rank': '220',
#   'scores_research': '88.2',
#   'scores_research_rank': '14',
#   'scores_teaching': '77.4',
#   'scores_teaching_rank': '19',
#   'stats_female_male_ratio': '51 : 49',
#   'stats_number_students': '30,602',
#   'stats_pc_intl_students': '30%',
#   'stats_student_staff_ratio': '17.0',
#   'subjects_offered': 'Architecture,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/national-university-singapore'},
#  {'aliases': 'University of Toronto',
#   'location': 'Canada',
#   'member_level': '0',
#   'name': 'University of Toronto',
#   'nid': 483,
#   'rank': '=22',
#   'rank_order': '230',
#   'record_type': 'master_account',
#   'scores_citations': '92.6',
#   'scores_citations_rank': '75',
#   'scores_industry_income': '46.5',
#   'scores_industry_income_rank': '329',
#   'scores_international_outlook': '80.1',
#   'scores_international_outlook_rank': '137',
#   'scores_overall': '82.8',
#   'scores_overall_rank': '230',
#   'scores_research': '84.8',
#   'scores_research_rank': '23',
#   'scores_teaching': '74.6',
#   'scores_teaching_rank': '24',
#   'stats_female_male_ratio': None,
#   'stats_number_students': '69,427',
#   'stats_pc_intl_students': '17%',
#   'stats_student_staff_ratio': '18.7',
#   'subjects_offered': 'Accounting & Finance,Agriculture & Forestry,Archaeology,Architecture,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology,Veterinary Science',
#   'url': '/world-university-rankings/university-toronto'},
#  {'aliases': 'Carnegie Mellon University',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'Carnegie Mellon University',
#   'nid': 485,
#   'rank': '24',
#   'rank_order': '240',
#   'record_type': 'private',
#   'scores_citations': '99.7',
#   'scores_citations_rank': '7',
#   'scores_industry_income': '50.4',
#   'scores_industry_income_rank': '277',
#   'scores_international_outlook': '79.1',
#   'scores_international_outlook_rank': '147',
#   'scores_overall': '81.9',
#   'scores_overall_rank': '240',
#   'scores_research': '83.7',
#   'scores_research_rank': '25',
#   'scores_teaching': '65.8',
#   'scores_teaching_rank': '36',
#   'stats_female_male_ratio': '39 : 61',
#   'stats_number_students': '12,676',
#   'stats_pc_intl_students': '45%',
#   'stats_student_staff_ratio': '13.5',
#   'subjects_offered': 'Accounting & Finance,Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/carnegie-mellon-university'},
#  {'aliases': 'London School of Economics and Political Science',
#   'location': 'United Kingdom',
#   'member_level': '0',
#   'name': 'London School of Economics and Political Science',
#   'nid': 511,
#   'rank': '=25',
#   'rank_order': '250',
#   'record_type': 'master_account',
#   'scores_citations': '94.9',
#   'scores_citations_rank': '53',
#   'scores_industry_income': '33.7',
#   'scores_industry_income_rank': '820',
#   'scores_international_outlook': '92.2',
#   'scores_international_outlook_rank': '43',
#   'scores_overall': '79.4',
#   'scores_overall_rank': '250',
#   'scores_research': '72.0',
#   'scores_research_rank': '43',
#   'scores_teaching': '71.8',
#   'scores_teaching_rank': '30',
#   'stats_female_male_ratio': '52 : 48',
#   'stats_number_students': '10,065',
#   'stats_pc_intl_students': '71%',
#   'stats_student_staff_ratio': '12.2',
#   'subjects_offered': 'Accounting & Finance,Business & Management,Economics & Econometrics,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Law,Mathematics & Statistics,Psychology,Sociology',
#   'url': '/world-university-rankings/london-school-economics-and-political-science'},
#  {'aliases': 'University of Washington',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'University of Washington',
#   'nid': 489,
#   'rank': '=25',
#   'rank_order': '260',
#   'record_type': 'public',
#   'scores_citations': '99.0',
#   'scores_citations_rank': '17',
#   'scores_industry_income': '47.3',
#   'scores_industry_income_rank': '319',
#   'scores_international_outlook': '56.5',
#   'scores_international_outlook_rank': '358',
#   'scores_overall': '79.4',
#   'scores_overall_rank': '260',
#   'scores_research': '79.9',
#   'scores_research_rank': '28',
#   'scores_teaching': '67.9',
#   'scores_teaching_rank': '34',
#   'stats_female_male_ratio': '52 : 48',
#   'stats_number_students': '44,945',
#   'stats_pc_intl_students': '16%',
#   'stats_student_staff_ratio': '11.4',
#   'subjects_offered': 'Accounting & Finance,Agriculture & Forestry,Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/university-washington'},
#  {'aliases': 'University of Edinburgh',
#   'location': 'United Kingdom',
#   'member_level': '0',
#   'name': 'University of Edinburgh',
#   'nid': 500,
#   'rank': '=27',
#   'rank_order': '270',
#   'record_type': 'master_account',
#   'scores_citations': '97.0',
#   'scores_citations_rank': '35',
#   'scores_industry_income': '36.3',
#   'scores_industry_income_rank': '645',
#   'scores_international_outlook': '92.0',
#   'scores_international_outlook_rank': '46',
#   'scores_overall': '79.2',
#   'scores_overall_rank': '270',
#   'scores_research': '74.2',
#   'scores_research_rank': '36',
#   'scores_teaching': '66.8',
#   'scores_teaching_rank': '35',
#   'stats_female_male_ratio': '59 : 41',
#   'stats_number_students': '26,759',
#   'stats_pc_intl_students': '40%',
#   'stats_student_staff_ratio': '12.5',
#   'subjects_offered': 'Accounting & Finance,Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology,Sport Science,Veterinary Science',
#   'url': '/world-university-rankings/university-edinburgh'},
#  {'aliases': 'New York University',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'New York University',
#   'nid': 508,
#   'rank': '=27',
#   'rank_order': '280',
#   'record_type': 'private',
#   'scores_citations': '96.5',
#   'scores_citations_rank': '43',
#   'scores_industry_income': '37.0',
#   'scores_industry_income_rank': '615',
#   'scores_international_outlook': '53.4',
#   'scores_international_outlook_rank': '394',
#   'scores_overall': '79.2',
#   'scores_overall_rank': '280',
#   'scores_research': '77.4',
#   'scores_research_rank': '34',
#   'scores_teaching': '73.7',
#   'scores_teaching_rank': '27',
#   'stats_female_male_ratio': '56 : 44',
#   'stats_number_students': '43,860',
#   'stats_pc_intl_students': '26%',
#   'stats_student_staff_ratio': '9.6',
#   'subjects_offered': 'Accounting & Finance,Archaeology,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/new-york-university'},
#  {'aliases': 'Peking University',
#   'location': 'China',
#   'member_level': '0',
#   'name': 'Peking University',
#   'nid': 514,
#   'rank': '=27',
#   'rank_order': '290',
#   'record_type': 'master_account',
#   'scores_citations': '74.2',
#   'scores_citations_rank': '274',
#   'scores_industry_income': '100.0',
#   'scores_industry_income_rank': '8',
#   'scores_international_outlook': '53.0',
#   'scores_international_outlook_rank': '404',
#   'scores_overall': '79.2',
#   'scores_overall_rank': '290',
#   'scores_research': '85.1',
#   'scores_research_rank': '22',
#   'scores_teaching': '83.0',
#   'scores_teaching_rank': '11',
#   'stats_female_male_ratio': '47 : 53',
#   'stats_number_students': '42,136',
#   'stats_pc_intl_students': '16%',
#   'stats_student_staff_ratio': '8.9',
#   'subjects_offered': 'Accounting & Finance,Archaeology,Art, Performing Arts & Design,Biological Sciences,Chemistry,Communication & Media Studies,Computer Science,Economics & Econometrics,General Engineering,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Other Health,Physics & Astronomy,Psychology',
#   'url': '/world-university-rankings/peking-university'},
#  {'aliases': 'Tsinghua University Qinghua University Tsing hua University Qing hua University',
#   'location': 'China',
#   'member_level': '6',
#   'name': 'Tsinghua University',
#   'nid': 535,
#   'rank': '30',
#   'rank_order': '300',
#   'record_type': 'master_account',
#   'scores_citations': '71.4',
#   'scores_citations_rank': '306',
#   'scores_industry_income': '99.8',
#   'scores_industry_income_rank': '19',
#   'scores_international_outlook': '41.0',
#   'scores_international_outlook_rank': '598',
#   'scores_overall': '79.0',
#   'scores_overall_rank': '300',
#   'scores_research': '93.2',
#   'scores_research_rank': '7',
#   'scores_teaching': '80.2',
#   'scores_teaching_rank': '16',
#   'stats_female_male_ratio': '32 : 68',
#   'stats_number_students': '42,089',
#   'stats_pc_intl_students': '9%',
#   'stats_student_staff_ratio': '13.7',
#   'subjects_offered': 'Accounting & Finance,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Civil Engineering,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Physics & Astronomy,Sport Science',
#   'url': '/world-university-rankings/tsinghua-university'},
#  {'aliases': 'University of California, San Diego',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'University of California, San Diego',
#   'nid': 497,
#   'rank': '31',
#   'rank_order': '310',
#   'record_type': 'public',
#   'scores_citations': '98.6',
#   'scores_citations_rank': '21',
#   'scores_industry_income': '96.5',
#   'scores_industry_income_rank': '37',
#   'scores_international_outlook': '51.9',
#   'scores_international_outlook_rank': '420',
#   'scores_overall': '78.7',
#   'scores_overall_rank': '310',
#   'scores_research': '79.8',
#   'scores_research_rank': '29',
#   'scores_teaching': '62.9',
#   'scores_teaching_rank': '43',
#   'stats_female_male_ratio': '46 : 54',
#   'stats_number_students': '29,633',
#   'stats_pc_intl_students': '17%',
#   'stats_student_staff_ratio': '12.8',
#   'subjects_offered': 'Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/university-california-san-diego'},
#  {'aliases': 'University of Melbourne',
#   'location': 'Australia',
#   'member_level': '11',
#   'name': 'University of Melbourne',
#   'nid': 501,
#   'rank': '32',
#   'rank_order': '320',
#   'record_type': 'master_account',
#   'scores_citations': '90.3',
#   'scores_citations_rank': '90',
#   'scores_industry_income': '70.1',
#   'scores_industry_income_rank': '131',
#   'scores_international_outlook': '92.7',
#   'scores_international_outlook_rank': '38',
#   'scores_overall': '77.5',
#   'scores_overall_rank': '320',
#   'scores_research': '74.2',
#   'scores_research_rank': '37',
#   'scores_teaching': '64.9',
#   'scores_teaching_rank': '39',
#   'stats_female_male_ratio': '55 : 45',
#   'stats_number_students': '42,116',
#   'stats_pc_intl_students': '40%',
#   'stats_student_staff_ratio': '26.6',
#   'subjects_offered': 'Accounting & Finance,Agriculture & Forestry,Archaeology,Architecture,Art, Performing Arts & Design,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology,Veterinary Science',
#   'url': '/world-university-rankings/university-melbourne'},
#  {'aliases': 'Georgia Institute of Technology',
#   'location': 'United States',
#   'member_level': '0',
#   'name': 'Georgia Institute of Technology',
#   'nid': 488,
#   'rank': '33',
#   'rank_order': '330',
#   'record_type': 'public',
#   'scores_citations': '94.3',
#   'scores_citations_rank': '61',
#   'scores_industry_income': '60.2',
#   'scores_industry_income_rank': '191',
#   'scores_international_outlook': '75.0',
#   'scores_international_outlook_rank': '185',
#   'scores_overall': '77.0',
#   'scores_overall_rank': '330',
#   'scores_research': '78.9',
#   'scores_research_rank': '30',
#   'scores_teaching': '59.7',
#   'scores_teaching_rank': '51',
#   'stats_female_male_ratio': '31 : 69',
#   'stats_number_students': '20,773',
#   'stats_pc_intl_students': '27%',
#   'stats_student_staff_ratio': '20.7',
#   'subjects_offered': 'Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Electrical & Electronic Engineering,General Engineering,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology',
#   'url': '/world-university-rankings/georgia-institute-technology'},
#  {'aliases': 'University of British Columbia',
#   'location': 'Canada',
#   'member_level': '0',
#   'name': 'University of British Columbia',
#   'nid': 486,
#   'rank': '=34',
#   'rank_order': '340',
#   'record_type': 'master_account',
#   'scores_citations': '93.4',
#   'scores_citations_rank': '67',
#   'scores_industry_income': '42.6',
#   'scores_industry_income_rank': '401',
#   'scores_international_outlook': '92.2',
#   'scores_international_outlook_rank': '42',
#   'scores_overall': '76.2',
#   'scores_overall_rank': '340',
#   'scores_research': '72.2',
#   'scores_research_rank': '40',
#   'scores_teaching': '61.8',
#   'scores_teaching_rank': '46',
#   'stats_female_male_ratio': '54 : 46',
#   'stats_number_students': '51,889',
#   'stats_pc_intl_students': '29%',
#   'stats_student_staff_ratio': '18.1',
#   'subjects_offered': 'Accounting & Finance,Agriculture & Forestry,Archaeology,Architecture,Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemical Engineering,Chemistry,Civil Engineering,Communication & Media Studies,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,General Engineering,Geography,Geology, Environmental, Earth & Marine Sciences,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Medicine & Dentistry,Other Health,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology,Sport Science',
#   'url': '/world-university-rankings/university-british-columbia'},
#  {'aliases': 'LMU Munich Ludwig-Maximilians-Universität München',
#   'location': 'Germany',
#   'member_level': '6',
#   'name': 'LMU Munich',
#   'nid': 509,
#   'rank': '=34',
#   'rank_order': '350',
#   'record_type': 'master_account',
#   'scores_citations': '91.3',
#   'scores_citations_rank': '84',
#   'scores_industry_income': '100.0',
#   'scores_industry_income_rank': '7',
#   'scores_international_outlook': '66.3',
#   'scores_international_outlook_rank': '256',
#   'scores_overall': '76.2',
#   'scores_overall_rank': '350',
#   'scores_research': '72.3',
# ...
#   'subjects_offered': 'Biological Sciences,Business & Management,Chemistry,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Languages, Literatures and Linguistics,Mechanical & Aerospace Engineering,Physics & Astronomy',
#   'url': '/world-university-rankings/vit-university'},
#  {'aliases': 'VŠB - Technical University of Ostrava',
#   'location': 'Czech Republic',
#   'member_level': '1',
#   'name': 'VŠB - Technical University of Ostrava',
#   'nid': 131319,
#   'rank': '801–1000',
#   'rank_order': '9870',
#   'record_type': 'master_account',
#   'scores_citations': '12.8',
#   'scores_citations_rank': '981',
#   'scores_industry_income': '39.5',
#   'scores_industry_income_rank': '499',
#   'scores_international_outlook': '30.4',
#   'scores_international_outlook_rank': '764',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9870',
#   'scores_research': '13.1',
#   'scores_research_rank': '741',
#   'scores_teaching': '18.6',
#   'scores_teaching_rank': '918',
#   'stats_female_male_ratio': None,
#   'stats_number_students': '18,270',
#   'stats_pc_intl_students': '8%',
#   'stats_student_staff_ratio': '23.4',
#   'subjects_offered': 'Civil Engineering,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,Mechanical & Aerospace Engineering',
#   'url': '/world-university-rankings/vsb-technical-university-ostrava'},
#  {'aliases': 'University of West Bohemia',
#   'location': 'Czech Republic',
#   'member_level': '0',
#   'name': 'University of West Bohemia',
#   'nid': 131333,
#   'rank': '801–1000',
#   'rank_order': '9880',
#   'record_type': 'master_account',
#   'scores_citations': '13.6',
#   'scores_citations_rank': '966',
#   'scores_industry_income': '35.7',
#   'scores_industry_income_rank': '688',
#   'scores_international_outlook': '26.4',
#   'scores_international_outlook_rank': '833',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9880',
#   'scores_research': '11.8',
#   'scores_research_rank': '808',
#   'scores_teaching': '18.5',
#   'scores_teaching_rank': '926',
#   'stats_female_male_ratio': '51 : 49',
#   'stats_number_students': '12,991',
#   'stats_pc_intl_students': '3%',
#   'stats_student_staff_ratio': '18.7',
#   'subjects_offered': 'Accounting & Finance,Archaeology,Architecture,Art, Performing Arts & Design,Business & Management,Computer Science,Economics & Econometrics,Electrical & Electronic Engineering,General Engineering,Geography,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Other Health,Physics & Astronomy,Sociology',
#   'url': '/world-university-rankings/university-west-bohemia'},
#  {'aliases': 'West University of Timişoara',
#   'location': 'Romania',
#   'member_level': '0',
#   'name': 'West University of Timişoara',
#   'nid': 131390,
#   'rank': '801–1000',
#   'rank_order': '9890',
#   'record_type': 'master_account',
#   'scores_citations': '26.3',
#   'scores_citations_rank': '777',
#   'scores_industry_income': '31.8',
#   'scores_industry_income_rank': '1058',
#   'scores_international_outlook': '30.7',
#   'scores_international_outlook_rank': '758',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9890',
#   'scores_research': '7.8',
#   'scores_research_rank': '1030',
#   'scores_teaching': '20.1',
#   'scores_teaching_rank': '821',
#   'stats_female_male_ratio': '65 : 35',
#   'stats_number_students': '13,524',
#   'stats_pc_intl_students': '4%',
#   'stats_student_staff_ratio': '17.0',
#   'subjects_offered': 'Art, Performing Arts & Design,Biological Sciences,Business & Management,Chemistry,Communication & Media Studies,Economics & Econometrics,Geography,History, Philosophy & Theology,Law,Mathematics & Statistics,Physics & Astronomy,Politics & International Studies (incl Development Studies),Psychology,Sociology,Sport Science',
#   'url': '/world-university-rankings/west-university-timisoara'},
#  {'aliases': 'University of Wrocław',
#   'location': 'Poland',
#   'member_level': '0',
#   'name': 'University of Wrocław',
#   'nid': 623118,
#   'rank': '801–1000',
#   'rank_order': '9900',
#   'record_type': 'master_account',
#   'scores_citations': '25.8',
#   'scores_citations_rank': '789',
#   'scores_industry_income': '33.8',
#   'scores_industry_income_rank': '812',
#   'scores_international_outlook': '32.5',
#   'scores_international_outlook_rank': '730',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9900',
#   'scores_research': '10.9',
#   'scores_research_rank': '853',
#   'scores_teaching': '20.1',
#   'scores_teaching_rank': '822',
#   'stats_female_male_ratio': None,
#   'stats_number_students': '23,852',
#   'stats_pc_intl_students': '3%',
#   'stats_student_staff_ratio': '12.9',
#   'subjects_offered': '',
#   'url': '/world-university-rankings/university-wroclaw'},
#  {'aliases': 'Wuhan University of Technology',
#   'location': 'China',
#   'member_level': '0',
#   'name': 'Wuhan University of Technology',
#   'nid': 929,
#   'rank': '801–1000',
#   'rank_order': '9910',
#   'record_type': 'master_account',
#   'scores_citations': '22.9',
#   'scores_citations_rank': '827',
#   'scores_industry_income': '54.8',
#   'scores_industry_income_rank': '230',
#   'scores_international_outlook': '19.0',
#   'scores_international_outlook_rank': '999',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9910',
#   'scores_research': '11.2',
#   'scores_research_rank': '839',
#   'scores_teaching': '19.0',
#   'scores_teaching_rank': '888',
#   'stats_female_male_ratio': '31 : 69',
#   'stats_number_students': '50,876',
#   'stats_pc_intl_students': '3%',
#   'stats_student_staff_ratio': '14.6',
#   'subjects_offered': 'Agriculture & Forestry,Computer Science,Economics & Econometrics,Education,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Medicine & Dentistry,Psychology,Veterinary Science',
#   'url': '/world-university-rankings/wuhan-university-technology'},
#  {'aliases': 'Xiangtan University',
#   'location': 'China',
#   'member_level': '0',
#   'name': 'Xiangtan University',
#   'nid': 587829,
#   'rank': '801–1000',
#   'rank_order': '9920',
#   'record_type': 'master_account',
#   'scores_citations': '35.6',
#   'scores_citations_rank': '662',
#   'scores_industry_income': '36.2',
#   'scores_industry_income_rank': '664',
#   'scores_international_outlook': '15.9',
#   'scores_international_outlook_rank': '1064',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9920',
#   'scores_research': '10.6',
#   'scores_research_rank': '870',
#   'scores_teaching': '15.3',
#   'scores_teaching_rank': '1081',
#   'stats_female_male_ratio': '53 : 47',
#   'stats_number_students': '30,810',
#   'stats_pc_intl_students': '1%',
#   'stats_student_staff_ratio': '21.2',
#   'subjects_offered': 'Accounting & Finance,Business & Management,Communication & Media Studies,Economics & Econometrics,General Engineering,History, Philosophy & Theology,Languages, Literatures and Linguistics,Law,Mathematics & Statistics,Mechanical & Aerospace Engineering,Politics & International Studies (incl Development Studies)',
#   'url': '/world-university-rankings/xiangtan-university'},
#  {'aliases': 'Xidian University',
#   'location': 'China',
#   'member_level': '0',
#   'name': 'Xidian University',
#   'nid': 1043,
#   'rank': '801–1000',
#   'rank_order': '9930',
#   'record_type': 'master_account',
#   'scores_citations': '16.4',
#   'scores_citations_rank': '923',
#   'scores_industry_income': '75.8',
#   'scores_industry_income_rank': '111',
#   'scores_international_outlook': '16.5',
#   'scores_international_outlook_rank': '1048',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9930',
#   'scores_research': '13.9',
#   'scores_research_rank': '710',
#   'scores_teaching': '19.7',
#   'scores_teaching_rank': '842',
#   'stats_female_male_ratio': '29 : 71',
#   'stats_number_students': '32,722',
#   'stats_pc_intl_students': '2%',
#   'stats_student_staff_ratio': '16.6',
#   'subjects_offered': 'Accounting & Finance,Business & Management,Chemistry,Computer Science,Electrical & Electronic Engineering,General Engineering,Mathematics & Statistics,Mechanical & Aerospace Engineering,Physics & Astronomy',
#   'url': '/world-university-rankings/xidian-university'},
#  {'aliases': 'Yamagata University',
#   'location': 'Japan',
#   'member_level': '0',
#   'name': 'Yamagata University',
#   'nid': 589193,
#   'rank': '801–1000',
#   'rank_order': '9940',
#   'record_type': 'master_account',
#   'scores_citations': '23.2',
#   'scores_citations_rank': '823',
#   'scores_industry_income': '49.9',
#   'scores_industry_income_rank': '284',
#   'scores_international_outlook': '20.3',
#   'scores_international_outlook_rank': '965',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9940',
#   'scores_research': '10.3',
#   'scores_research_rank': '885',
#   'scores_teaching': '21.0',
#   'scores_teaching_rank': '761',
#   'stats_female_male_ratio': '35 : 65',
#   'stats_number_students': '8,961',
#   'stats_pc_intl_students': '1%',
#   'stats_student_staff_ratio': '8.2',
#   'subjects_offered': 'Architecture,Business & Management,Chemistry,Civil Engineering,Computer Science,Economics & Econometrics,Education,Electrical & Electronic Engineering,General Engineering,Geology, Environmental, Earth & Marine Sciences,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Physics & Astronomy,Politics & International Studies (incl Development Studies),Sociology,Sport Science,Veterinary Science,Other Health',
#   'url': '/world-university-rankings/yamagata-university'},
#  {'aliases': 'Yamaguchi University',
#   'location': 'Japan',
#   'member_level': '0',
#   'name': 'Yamaguchi University',
#   'nid': 131669,
#   'rank': '801–1000',
#   'rank_order': '9950',
#   'record_type': 'master_account',
#   'scores_citations': '12.6',
#   'scores_citations_rank': '984',
#   'scores_industry_income': '38.9',
#   'scores_industry_income_rank': '528',
#   'scores_international_outlook': '22.3',
#   'scores_international_outlook_rank': '914',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9950',
#   'scores_research': '9.3',
#   'scores_research_rank': '944',
#   'scores_teaching': '21.8',
#   'scores_teaching_rank': '715',
#   'stats_female_male_ratio': '35 : 65',
#   'stats_number_students': '10,639',
#   'stats_pc_intl_students': '4%',
#   'stats_student_staff_ratio': '11.0',
#   'subjects_offered': 'Accounting & Finance,Art, Performing Arts & Design,Business & Management,Communication & Media Studies,Computer Science,Economics & Econometrics,Education,General Engineering,Geography,History, Philosophy & Theology,Languages, Literatures and Linguistics,Medicine & Dentistry,Other Health,Psychology,Sociology,Sport Science',
#   'url': '/world-university-rankings/yamaguchi-university'},
#  {'aliases': 'University of Yamanashi',
#   'location': 'Japan',
#   'member_level': '0',
#   'name': 'University of Yamanashi',
#   'nid': 589280,
#   'rank': '801–1000',
#   'rank_order': '9960',
#   'record_type': 'master_account',
#   'scores_citations': '21.7',
#   'scores_citations_rank': '837',
#   'scores_industry_income': '34.4',
#   'scores_industry_income_rank': '766',
#   'scores_international_outlook': '21.2',
#   'scores_international_outlook_rank': '937',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9960',
#   'scores_research': '10.5',
#   'scores_research_rank': '872',
#   'scores_teaching': '24.2',
#   'scores_teaching_rank': '590',
#   'stats_female_male_ratio': '30 : 70',
#   'stats_number_students': '4,777',
#   'stats_pc_intl_students': '4%',
#   'stats_student_staff_ratio': '6.7',
#   'subjects_offered': 'Education,General Engineering,Medicine & Dentistry',
#   'url': '/world-university-rankings/university-yamanashi'},
#  {'aliases': 'Yıldız Technical University',
#   'location': 'Turkey',
#   'member_level': '0',
#   'name': 'Yıldız Technical University',
#   'nid': 131735,
#   'rank': '801–1000',
#   'rank_order': '9970',
#   'record_type': 'master_account',
#   'scores_citations': '26.6',
#   'scores_citations_rank': '769',
#   'scores_industry_income': '42.6',
#   'scores_industry_income_rank': '403',
#   'scores_international_outlook': '20.5',
#   'scores_international_outlook_rank': '958',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9970',
#   'scores_research': '7.7',
#   'scores_research_rank': '1036',
#   'scores_teaching': '18.7',
#   'scores_teaching_rank': '910',
#   'stats_female_male_ratio': '38 : 62',
#   'stats_number_students': '35,670',
#   'stats_pc_intl_students': '4%',
#   'stats_student_staff_ratio': '28.5',
#   'subjects_offered': 'Biological Sciences,Chemistry,Education,Electrical & Electronic Engineering,General Engineering,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mathematics & Statistics,Mechanical & Aerospace Engineering,Sociology',
#   'url': '/world-university-rankings/yildiz-technical-university'},
#  {'aliases': 'Yokohama National University',
#   'location': 'Japan',
#   'member_level': '0',
#   'name': 'Yokohama National University',
#   'nid': 955,
#   'rank': '801–1000',
#   'rank_order': '9980',
#   'record_type': 'master_account',
#   'scores_citations': '14.6',
#   'scores_citations_rank': '951',
#   'scores_industry_income': '45.5',
#   'scores_industry_income_rank': '350',
#   'scores_international_outlook': '24.2',
#   'scores_international_outlook_rank': '871',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9980',
#   'scores_research': '21.8',
#   'scores_research_rank': '478',
#   'scores_teaching': '22.8',
#   'scores_teaching_rank': '665',
#   'stats_female_male_ratio': '28 : 72',
#   'stats_number_students': '9,968',
#   'stats_pc_intl_students': '7%',
#   'stats_student_staff_ratio': '12.8',
#   'subjects_offered': 'Art, Performing Arts & Design,Business & Management,Economics & Econometrics,Education,General Engineering',
#   'url': '/world-university-rankings/yokohama-national-university'},
#  {'aliases': 'Yuan Ze University',
#   'location': 'Taiwan',
#   'member_level': '0',
#   'name': 'Yuan Ze University',
#   'nid': 865,
#   'rank': '801–1000',
#   'rank_order': '9990',
#   'record_type': 'master_account',
#   'scores_citations': '25.9',
#   'scores_citations_rank': '787',
#   'scores_industry_income': '47.1',
#   'scores_industry_income_rank': '320',
#   'scores_international_outlook': '22.6',
#   'scores_international_outlook_rank': '903',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '9990',
#   'scores_research': '15.0',
#   'scores_research_rank': '674',
#   'scores_teaching': '18.8',
#   'scores_teaching_rank': '905',
#   'stats_female_male_ratio': '42 : 58',
#   'stats_number_students': '8,652',
#   'stats_pc_intl_students': '6%',
#   'stats_student_staff_ratio': '20.9',
#   'subjects_offered': 'Art, Performing Arts & Design,Business & Management,Chemical Engineering,Computer Science,Education,Electrical & Electronic Engineering,General Engineering,History, Philosophy & Theology,Languages, Literatures and Linguistics,Mechanical & Aerospace Engineering',
#   'url': '/world-university-rankings/yuan-ze-university'},
#  {'aliases': 'University of Zagreb',
#   'location': 'Croatia',
#   'member_level': '0',
#   'name': 'University of Zagreb',
#   'nid': 589178,
#   'rank': '801–1000',
#   'rank_order': '10000',
#   'record_type': 'master_account',
#   'scores_citations': '20.3',
#   'scores_citations_rank': '859',
#   'scores_industry_income': '41.6',
#   'scores_industry_income_rank': '429',
#   'scores_international_outlook': '28.5',
#   'scores_international_outlook_rank': '800',
#   'scores_overall': '15.6–21.4',
#   'scores_overall_rank': '10000',
#   'scores_research': '11.1',
#   'scores_research_rank': '843',
#   'scores_teaching': '21.0',
#   'scores_teaching_rank': '762',
#   'stats_female_male_ratio': '55 : 45',
#   'stats_number_students': '73,465',
#   'stats_pc_intl_students': '1%',
#   'stats_student_staff_ratio': '17.4',
#   'subjects_offered': 'Accounting & Finance,Architecture,Art, Performing Arts & Design,Business & Management,Civil Engineering,Communication & Media Studies,Computer Science,Education,Electrical & Electronic Engineering,General Engineering,Law,Mechanical & Aerospace Engineering,Medicine & Dentistry,Other Health,Physics & Astronomy,Psychology,Sport Science',
#   'url': '/world-university-rankings/university-zagreb'},
#  ...]

# %% [markdown]
# JSON from the beggining is back to match Region with countrys from time rankins

# %%
data2=data.get('data')
data2
# Out:
# [{'cc': 'US',
#   'core_id': '410',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/massachusetts-institute-of-technology-mit_410_small_0.jpg" alt="Massachusetts Institute of Technology (MIT)  Logo">',
#   'nid': '294850',
#   'rank_display': '1',
#   'region': 'North America',
#   'score': '100',
#   'stars': '6',
#   'title': 'Massachusetts Institute of Technology (MIT)',
#   'url': '/universities/massachusetts-institute-technology-mit'},
#  {'cc': 'US',
#   'core_id': '573',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/stanford-university_573_small_0.jpg" alt="Stanford University Logo">',
#   'nid': '297282',
#   'rank_display': '2',
#   'region': 'North America',
#   'score': '98.7',
#   'stars': '5',
#   'title': 'Stanford University',
#   'url': '/universities/stanford-university'},
#  {'cc': 'US',
#   'core_id': '253',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/harvard-university_253_small_0.jpg" alt="Harvard University Logo">',
#   'nid': '294270',
#   'rank_display': '3',
#   'region': 'North America',
#   'score': '98.4',
#   'stars': '5',
#   'title': 'Harvard University',
#   'url': '/universities/harvard-university'},
#  {'cc': 'US',
#   'core_id': '94',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/california-institute-of-technology-caltech_94_small_1.jpg" alt="California Institute of Technology (Caltech) Logo">',
#   'nid': '294562',
#   'rank_display': '4',
#   'region': 'North America',
#   'score': '97.7',
#   'stars': '5',
#   'title': 'California Institute of Technology (Caltech)',
#   'url': '/universities/california-institute-technology-caltech'},
#  {'cc': 'GB',
#   'core_id': '95',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-cambridge_95_small_1.jpg" alt="University of Cambridge Logo">',
#   'nid': '294561',
#   'rank_display': '5',
#   'region': 'Europe',
#   'score': '95.6',
#   'stars': '5',
#   'title': 'University of Cambridge',
#   'url': '/universities/university-cambridge'},
#  {'cc': 'GB',
#   'core_id': '478',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-oxford_478_small_0.jpg" alt="University of Oxford Logo">',
#   'nid': '294654',
#   'rank_display': '6',
#   'region': 'Europe',
#   'score': '95.3',
#   'stars': '5',
#   'title': 'University of Oxford',
#   'url': '/universities/university-oxford'},
#  {'cc': 'GB',
#   'core_id': '365',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/ucl-university-college-london_365_small_0.jpg" alt="UCL (University College London) Logo">',
#   'nid': '294014',
#   'rank_display': '7',
#   'region': 'Europe',
#   'score': '94.6',
#   'stars': None,
#   'title': 'UCL (University College London)',
#   'url': '/universities/ucl-university-college-london'},
#  {'cc': 'GB',
#   'core_id': '356',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/imperial-college-london_356_small.jpg" alt="Imperial College London Logo">',
#   'nid': '294030',
#   'rank_display': '8',
#   'region': 'Europe',
#   'score': '93.7',
#   'stars': None,
#   'title': 'Imperial College London',
#   'url': '/universities/imperial-college-london'},
#  {'cc': 'US',
#   'core_id': '120',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-chicago_120_small_0.jpg" alt="University of Chicago Logo">',
#   'nid': '294536',
#   'rank_display': '9',
#   'region': 'North America',
#   'score': '93.5',
#   'stars': '5',
#   'title': 'University of Chicago',
#   'url': '/universities/university-chicago'},
#  {'cc': 'CH',
#   'core_id': '201',
#   'country': 'Switzerland',
#   'guide': '<a href="/where-to-study/europe/switzerland/guide" class="guide-link" target="_blank">Switzerland</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/eth-zurich-swiss-federal-institute-of-technology_201_small_0.jpg" alt="ETH Zurich - Swiss Federal Institute of Technology Logo">',
#   'nid': '294432',
#   'rank_display': '10',
#   'region': 'Europe',
#   'score': '93.3',
#   'stars': None,
#   'title': 'ETH Zurich - Swiss Federal Institute of Technology',
#   'url': '/universities/eth-zurich-swiss-federal-institute-technology'},
#  {'cc': 'SG',
#   'core_id': '431',
#   'country': 'Singapore',
#   'guide': '',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/nanyang-technological-university-singapore-ntu_431_small_2.jpg" alt="Nanyang Technological University, Singapore (NTU) Logo">',
#   'nid': '294821',
#   'rank_display': '11',
#   'region': 'Asia',
#   'score': '92.2',
#   'stars': '6',
#   'title': 'Nanyang Technological University, Singapore (NTU)',
#   'url': '/universities/nanyang-technological-university-singapore-ntu'},
#  {'cc': 'CH',
#   'core_id': '177',
#   'country': 'Switzerland',
#   'guide': '<a href="/where-to-study/europe/switzerland/guide" class="guide-link" target="_blank">Switzerland</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/ecole-polytechnique-fdrale-de-lausanne-epfl_177_small_1.jpg" alt="Ecole Polytechnique Fédérale de Lausanne (EPFL) Logo">',
#   'nid': '294481',
#   'rank_display': '12',
#   'region': 'Europe',
#   'score': '91.2',
#   'stars': None,
#   'title': 'Ecole Polytechnique Fédérale de Lausanne (EPFL)',
#   'url': '/universities/ecole-polytechnique-f%C3%A9d%C3%A9rale-de-lausanne-epfl'},
#  {'cc': 'US',
#   'core_id': '508',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/princeton-university_508_small_0.jpg" alt="Princeton University Logo">',
#   'nid': '297490',
#   'rank_display': '13',
#   'region': 'North America',
#   'score': '91',
#   'stars': '5',
#   'title': 'Princeton University',
#   'url': '/universities/princeton-university'},
#  {'cc': 'US',
#   'core_id': '143',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/cornell-university_143_small_0.jpg" alt="Cornell University Logo">',
#   'nid': '294514',
#   'rank_display': '14',
#   'region': 'North America',
#   'score': '90.7',
#   'stars': '5',
#   'title': 'Cornell University',
#   'url': '/universities/cornell-university'},
#  {'cc': 'SG',
#   'core_id': '443',
#   'country': 'Singapore',
#   'guide': '',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/national-university-of-singapore-nus_443_small_0.jpg" alt="National University of Singapore (NUS) Logo">',
#   'nid': '294798',
#   'rank_display': '15',
#   'region': 'Asia',
#   'score': '90.5',
#   'stars': None,
#   'title': 'National University of Singapore (NUS)',
#   'url': '/universities/national-university-singapore-nus'},
#  {'cc': 'US',
#   'core_id': '684',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/yale-university_684_small_1.jpg" alt="Yale University Logo">',
#   'nid': '297177',
#   'rank_display': '16',
#   'region': 'North America',
#   'score': '90.4',
#   'stars': '5',
#   'title': 'Yale University',
#   'url': '/universities/yale-university'},
#  {'cc': 'US',
#   'core_id': '305',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/johns-hopkins-university_305_small_0.jpg" alt="Johns Hopkins University Logo">',
#   'nid': '294184',
#   'rank_display': '17',
#   'region': 'North America',
#   'score': '89.8',
#   'stars': None,
#   'title': 'Johns Hopkins University',
#   'url': '/universities/johns-hopkins-university'},
#  {'cc': 'US',
#   'core_id': '138',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/columbia-university_138_small_0.jpg" alt="Columbia University Logo">',
#   'nid': '294519',
#   'rank_display': '18',
#   'region': 'North America',
#   'score': '88.9',
#   'stars': '5',
#   'title': 'Columbia University',
#   'url': '/universities/columbia-university'},
#  {'cc': 'US',
#   'core_id': '495',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-pennsylvania_495_small.jpg" alt="University of Pennsylvania Logo">',
#   'nid': '297569',
#   'rank_display': '19',
#   'region': 'North America',
#   'score': '88.7',
#   'stars': '5',
#   'title': 'University of Pennsylvania',
#   'url': '/universities/university-pennsylvania'},
#  {'cc': 'AU',
#   'core_id': '40',
#   'country': 'Australia',
#   'guide': '<a href="/where-to-study/oceania/australia/guide" class="guide-link" target="_blank">Australia</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-australian-national-university_40_small_0.jpg" alt="The Australian National University Logo">',
#   'nid': '294616',
#   'rank_display': '20',
#   'region': 'Oceania',
#   'score': '87.1',
#   'stars': '',
#   'title': 'The Australian National University',
#   'url': '/universities/australian-national-university'},
#  {'cc': 'US',
#   'core_id': '403',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-michigan_403_small_0.jpg" alt="University of Michigan Logo">',
#   'nid': '294857',
#   'rank_display': '=21',
#   'region': 'North America',
#   'score': '87',
#   'stars': '5',
#   'title': 'University of Michigan',
#   'url': '/universities/university-michigan'},
#  {'cc': 'US',
#   'core_id': '168',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/duke-university_168_small_0.jpg" alt="Duke University Logo">',
#   'nid': '294490',
#   'rank_display': '=21',
#   'region': 'North America',
#   'score': '87',
#   'stars': '5',
#   'title': 'Duke University',
#   'url': '/universities/duke-university'},
#  {'cc': 'GB',
#   'core_id': '180',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-edinburgh_180_small.jpg" alt="The University of Edinburgh Logo">',
#   'nid': '294478',
#   'rank_display': '=23',
#   'region': 'Europe',
#   'score': '86.9',
#   'stars': None,
#   'title': 'The University of Edinburgh',
#   'url': '/universities/university-edinburgh'},
#  {'cc': 'GB',
#   'core_id': '357',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/kings-college-london_357_small.jpg" alt="King\'s College London Logo">',
#   'nid': '294029',
#   'rank_display': '=23',
#   'region': 'Europe',
#   'score': '86.9',
#   'stars': None,
#   'title': "King's College London",
#   'url': '/universities/kings-college-london'},
#  {'cc': 'CN',
#   'core_id': '626',
#   'country': 'China',
#   'guide': '<a href="/where-to-study/asia/china/guide" class="guide-link" target="_blank">China</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/tsinghua-university_626_small_1.jpg" alt="Tsinghua University Logo">',
#   'nid': '297235',
#   'rank_display': '25',
#   'region': 'Asia',
#   'score': '85.6',
#   'stars': None,
#   'title': 'Tsinghua University',
#   'url': '/universities/tsinghua-university'},
#  {'cc': 'HK',
#   'core_id': '268',
#   'country': 'Hong Kong',
#   'guide': '<a href="/where-to-study/asia/hong-kong/guide" class="guide-link" target="_blank">Hong Kong</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-hong-kong_268_small.jpg" alt="The University of Hong Kong Logo">',
#   'nid': '294256',
#   'rank_display': '26',
#   'region': 'Asia',
#   'score': '85.5',
#   'stars': None,
#   'title': 'The University of Hong Kong',
#   'url': '/universities/university-hong-kong'},
#  {'cc': 'US',
#   'core_id': '84',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-california-berkeley-ucb_84_small.jpg" alt="University of California, Berkeley (UCB) Logo">',
#   'nid': '294572',
#   'rank_display': '27',
#   'region': 'North America',
#   'score': '84.9',
#   'stars': None,
#   'title': 'University of California, Berkeley (UCB)',
#   'url': '/universities/university-california-berkeley-ucb'},
#  {'cc': 'JP',
#   'core_id': '615',
#   'country': 'Japan',
#   'guide': '<a href="/where-to-study/asia/japan/guide" class="guide-link" target="_blank">Japan</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-tokyo_615_small.jpg" alt="The University of Tokyo Logo">',
#   'nid': '297246',
#   'rank_display': '=28',
#   'region': 'Asia',
#   'score': '84.8',
#   'stars': None,
#   'title': 'The University of Tokyo',
#   'url': '/universities/university-tokyo'},
#  {'cc': 'US',
#   'core_id': '456',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/northwestern-university_456_small_0.jpg" alt="Northwestern University Logo">',
#   'nid': '294767',
#   'rank_display': '=28',
#   'region': 'North America',
#   'score': '84.8',
#   'stars': None,
#   'title': 'Northwestern University',
#   'url': '/universities/northwestern-university'},
#  {'cc': 'HK',
#   'core_id': '269',
#   'country': 'Hong Kong',
#   'guide': '<a href="/where-to-study/asia/hong-kong/guide" class="guide-link" target="_blank">Hong Kong</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-hong-kong-university-of-science-and-technology_269_small_1.jpg" alt="The Hong Kong University of Science and Technology Logo">',
#   'nid': '294255',
#   'rank_display': '30',
#   'region': 'Asia',
#   'score': '84.3',
#   'stars': None,
#   'title': 'The Hong Kong University of Science and Technology',
#   'url': '/universities/hong-kong-university-science-technology'},
#  {'cc': 'CA',
#   'core_id': '619',
#   'country': 'Canada',
#   'guide': '<a href="/where-to-study/north-america/canada/guide" class="guide-link" target="_blank">Canada</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-toronto_619_small.jpg" alt="University of Toronto Logo">',
#   'nid': '297242',
#   'rank_display': '31',
#   'region': 'North America',
#   'score': '84',
#   'stars': None,
#   'title': 'University of Toronto',
#   'url': '/universities/university-toronto'},
#  {'cc': 'CA',
#   'core_id': '396',
#   'country': 'Canada',
#   'guide': '<a href="/where-to-study/north-america/canada/guide" class="guide-link" target="_blank">Canada</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/mcgill-university_592560cf2aeae70239af4c10_small.jpg" alt="McGill University Logo">',
#   'nid': '294864',
#   'rank_display': '32',
#   'region': 'North America',
#   'score': '83.9',
#   'stars': None,
#   'title': 'McGill University',
#   'url': '/universities/mcgill-university'},
#  {'cc': 'US',
#   'core_id': '87',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-california-los-angeles-ucla_87_small.jpg" alt="University of California, Los Angeles (UCLA) Logo">',
#   'nid': '294569',
#   'rank_display': '33',
#   'region': 'North America',
#   'score': '83.6',
#   'stars': None,
#   'title': 'University of California, Los Angeles (UCLA)',
#   'url': '/universities/university-california-los-angeles-ucla'},
#  {'cc': 'GB',
#   'core_id': '389',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-manchester_389_small.jpg" alt="The University of Manchester Logo">',
#   'nid': '294871',
#   'rank_display': '34',
#   'region': 'Europe',
#   'score': '83',
#   'stars': None,
#   'title': 'The University of Manchester',
#   'url': '/universities/university-manchester'},
#  {'cc': 'GB',
#   'core_id': '362',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/london-school-of-economics-and-political-science-lse_362_small_1.jpg" alt="London School of Economics and Political Science (LSE) Logo">',
#   'nid': '294016',
#   'rank_display': '35',
#   'region': 'Europe',
#   'score': '81.8',
#   'stars': None,
#   'title': 'London School of Economics and Political Science (LSE)',
#   'url': '/universities/london-school-economics-political-science-lse'},
#  {'cc': 'JP',
#   'core_id': '328',
#   'country': 'Japan',
#   'guide': '<a href="/where-to-study/asia/japan/guide" class="guide-link" target="_blank">Japan</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/kyoto-university_328_small.jpg" alt="Kyoto University Logo">',
#   'nid': '294111',
#   'rank_display': '=36',
#   'region': 'Asia',
#   'score': '81.5',
#   'stars': None,
#   'title': 'Kyoto University',
#   'url': '/universities/kyoto-university'},
#  {'cc': 'KR',
#   'core_id': '553',
#   'country': 'South Korea',
#   'guide': '<a href="/where-to-study/asia/south-korea/guide" class="guide-link" target="_blank">South Korea</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/graduate-school-of-business-seoul-national-university_553_small.jpg" alt="Seoul National University Logo">',
#   'nid': '297403',
#   'rank_display': '=36',
#   'region': 'Asia',
#   'score': '81.5',
#   'stars': '',
#   'title': 'Seoul National University',
#   'url': '/universities/seoul-national-university'},
#  {'cc': 'CN',
#   'core_id': '50',
#   'country': 'China',
#   'guide': '<a href="/where-to-study/asia/china/guide" class="guide-link" target="_blank">China</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/peking-university_50_small.jpg" alt="Peking University Logo">',
#   'nid': '294606',
#   'rank_display': '=38',
#   'region': 'Asia',
#   'score': '80.8',
#   'stars': None,
#   'title': 'Peking University',
#   'url': '/universities/peking-university'},
#  {'cc': 'US',
#   'core_id': '89',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-california-san-diego-ucsd_89_small.jpg" alt="University of California, San Diego (UCSD) Logo">',
#   'nid': '294567',
#   'rank_display': '=38',
#   'region': 'North America',
#   'score': '80.8',
#   'stars': None,
#   'title': 'University of California, San Diego (UCSD)',
#   'url': '/universities/university-california-san-diego-ucsd'},
#  {'cc': 'CN',
#   'core_id': '218',
#   'country': 'China',
#   'guide': '<a href="/where-to-study/asia/china/guide" class="guide-link" target="_blank">China</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/fudan-university_218_small_0.jpg" alt="Fudan University Logo">',
#   'nid': '294367',
#   'rank_display': '40',
#   'region': 'Asia',
#   'score': '80.6',
#   'stars': None,
#   'title': 'Fudan University',
#   'url': '/universities/fudan-university'},
#  {'cc': 'KR',
#   'core_id': '324',
#   'country': 'South Korea',
#   'guide': '<a href="/where-to-study/asia/south-korea/guide" class="guide-link" target="_blank">South Korea</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/kaist-korea-advanced-institute-of-science-technology_324_small.jpg" alt="KAIST - Korea Advanced Institute of Science & Technology Logo">',
#   'nid': '294124',
#   'rank_display': '=41',
#   'region': 'Asia',
#   'score': '80.4',
#   'stars': None,
#   'title': 'KAIST - Korea Advanced Institute of Science & Technology',
#   'url': '/universities/kaist-korea-advanced-institute-science-technology'},
#  {'cc': 'AU',
#   'core_id': '399',
#   'country': 'Australia',
#   'guide': '<a href="/where-to-study/oceania/australia/guide" class="guide-link" target="_blank">Australia</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-melbourne_399_small_1.jpg" alt="The University of Melbourne Logo">',
#   'nid': '294861',
#   'rank_display': '=41',
#   'region': 'Oceania',
#   'score': '80.4',
#   'stars': None,
#   'title': 'The University of Melbourne',
#   'url': '/universities/university-melbourne'},
#  {'cc': 'FR',
#   'core_id': '176',
#   'country': 'France',
#   'guide': '<a href="/where-to-study/europe/france/guide" class="guide-link" target="_blank">France</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/ecole-normale-suprieure-paris_176_small_0.jpg" alt="Ecole normale supérieure, Paris Logo">',
#   'nid': '294482',
#   'rank_display': '43',
#   'region': 'Europe',
#   'score': '79.9',
#   'stars': None,
#   'title': 'Ecole normale supérieure, Paris',
#   'url': '/universities/ecole-normale-sup%C3%A9rieure-paris'},
#  {'cc': 'GB',
#   'core_id': '69',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-bristol_69_small_3.jpg" alt="University of Bristol Logo">',
#   'nid': '294587',
#   'rank_display': '44',
#   'region': 'Europe',
#   'score': '79.5',
#   'stars': None,
#   'title': 'University of Bristol',
#   'url': '/universities/university-bristol'},
#  {'cc': 'AU',
#   'core_id': '447',
#   'country': 'Australia',
#   'guide': '<a href="/where-to-study/oceania/australia/guide" class="guide-link" target="_blank">Australia</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-new-south-wales-unsw-sydney_447_small_0.jpg" alt="The University of New South Wales (UNSW Sydney) Logo">',
#   'nid': '294788',
#   'rank_display': '45',
#   'region': 'Oceania',
#   'score': '78.9',
#   'stars': '6',
#   'title': 'The University of New South Wales (UNSW Sydney)',
#   'url': '/universities/university-new-south-wales-unsw-sydney'},
#  {'cc': 'HK',
#   'core_id': '123',
#   'country': 'Hong Kong',
#   'guide': '<a href="/where-to-study/asia/hong-kong/guide" class="guide-link" target="_blank">Hong Kong</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-chinese-university-of-hong-kong-cuhk_123_small_1.jpg" alt="The Chinese University of Hong Kong (CUHK) Logo">',
#   'nid': '294277',
#   'rank_display': '46',
#   'region': 'Asia',
#   'score': '78.8',
#   'stars': None,
#   'title': 'The Chinese University of Hong Kong (CUHK)',
#   'url': '/universities/chinese-university-hong-kong-cuhk'},
#  {'cc': 'AU',
#   'core_id': '515',
#   'country': 'Australia',
#   'guide': '<a href="/where-to-study/oceania/australia/guide" class="guide-link" target="_blank">Australia</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-queensland_515_small_1.jpg" alt="The University of Queensland Logo">',
#   'nid': '297460',
#   'rank_display': '=47',
#   'region': 'Oceania',
#   'score': '78.6',
#   'stars': '',
#   'title': 'The University of Queensland',
#   'url': '/universities/university-queensland'},
#  {'cc': 'US',
#   'core_id': '101',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/carnegie-mellon-university_101_small.jpg" alt="Carnegie Mellon University Logo">',
#   'nid': '294555',
#   'rank_display': '=47',
#   'region': 'North America',
#   'score': '78.6',
#   'stars': None,
#   'title': 'Carnegie Mellon University',
#   'url': '/universities/carnegie-mellon-university'},
#  {'cc': 'HK',
#   'core_id': '130',
#   'country': 'Hong Kong',
#   'guide': '<a href="/where-to-study/asia/hong-kong/guide" class="guide-link" target="_blank">Hong Kong</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/city-university-of-hong-kong_130_small.jpg" alt="City University of Hong Kong Logo">',
#   'nid': '294527',
#   'rank_display': '49',
#   'region': 'Asia',
#   'score': '78.4',
#   'stars': '6',
#   'title': 'City University of Hong Kong',
#   'url': '/universities/city-university-hong-kong'},
#  {'cc': 'AU',
#   'core_id': '588',
#   'country': 'Australia',
#   'guide': '<a href="/where-to-study/oceania/australia/guide" class="guide-link" target="_blank">Australia</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-sydney_592560cf2aeae70239af4cd0_small.jpg" alt="The University of Sydney Logo">',
#   'nid': '296815',
#   'rank_display': '50',
#   'region': 'Oceania',
#   'score': '78',
#   'stars': '6',
#   'title': 'The University of Sydney',
#   'url': '/universities/university-sydney'},
#  {'cc': 'CA',
#   'core_id': '70',
#   'country': 'Canada',
#   'guide': '<a href="/where-to-study/north-america/canada/guide" class="guide-link" target="_blank">Canada</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-british-columbia_70_small.jpg" alt="University of British Columbia Logo">',
#   'nid': '294586',
#   'rank_display': '51',
#   'region': 'North America',
#   'score': '77.9',
#   'stars': None,
#   'title': 'University of British Columbia',
#   'url': '/universities/university-british-columbia'},
#  {'cc': 'US',
#   'core_id': '448',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/new-york-university-nyu_448_small_0.jpg" alt="New York University (NYU) Logo">',
#   'nid': '294786',
#   'rank_display': '52',
#   'region': 'North America',
#   'score': '77.3',
#   'stars': '5',
#   'title': 'New York University (NYU)',
#   'url': '/universities/new-york-university-nyu'},
#  {'cc': 'US',
#   'core_id': '72',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/brown-university_72_small_0.jpg" alt="Brown University Logo">',
#   'nid': '294584',
#   'rank_display': '53',
#   'region': 'North America',
#   'score': '76.5',
#   'stars': None,
#   'title': 'Brown University',
#   'url': '/universities/brown-university'},
#  {'cc': 'NL',
#   'core_id': '155',
#   'country': 'Netherlands',
#   'guide': '<a href="/where-to-study/europe/netherlands/guide" class="guide-link" target="_blank">Netherlands</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/delft-university-of-technology_155_small.jpg" alt="Delft University of Technology Logo">',
#   'nid': '294502',
#   'rank_display': '54',
#   'region': 'Europe',
#   'score': '76.1',
#   'stars': None,
#   'title': 'Delft University of Technology',
#   'url': '/universities/delft-university-technology'},
#  {'cc': 'US',
#   'core_id': '678',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-wisconsin-madison_678_small.jpg" alt="University of Wisconsin-Madison Logo">',
#   'nid': '297183',
#   'rank_display': '55',
#   'region': 'North America',
#   'score': '75.8',
#   'stars': '5',
#   'title': 'University of Wisconsin-Madison',
#   'url': '/universities/university-wisconsin-madison'},
#  {'cc': 'JP',
#   'core_id': '613',
#   'country': 'Japan',
#   'guide': '<a href="/where-to-study/asia/japan/guide" class="guide-link" target="_blank">Japan</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/tokyo-institute-of-technology_613_small_0.jpg" alt="Tokyo Institute of Technology Logo">',
#   'nid': '297248',
#   'rank_display': '56',
#   'region': 'Asia',
#   'score': '74.8',
#   'stars': None,
#   'title': 'Tokyo Institute of Technology',
#   'url': '/universities/tokyo-institute-technology'},
#  {'cc': 'GB',
#   'core_id': '664',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-warwick_664_small_0.jpg" alt="The University of Warwick Logo">',
#   'nid': '297197',
#   'rank_display': '57',
#   'region': 'Europe',
#   'score': '74.4',
#   'stars': None,
#   'title': 'The University of Warwick',
#   'url': '/universities/university-warwick'},
#  {'cc': 'NL',
#   'core_id': '18',
#   'country': 'Netherlands',
#   'guide': '<a href="/where-to-study/europe/netherlands/guide" class="guide-link" target="_blank">Netherlands</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-amsterdam_18_small_1.jpg" alt="University of Amsterdam Logo">',
#   'nid': '297816',
#   'rank_display': '58',
#   'region': 'Europe',
#   'score': '74.3',
#   'stars': None,
#   'title': 'University of Amsterdam',
#   'url': '/universities/university-amsterdam'},
#  {'cc': 'FR',
#   'core_id': '178',
#   'country': 'France',
#   'guide': '<a href="/where-to-study/europe/france/guide" class="guide-link" target="_blank">France</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/ecole-polytechnique_178_small_1.jpg" alt="Ecole Polytechnique Logo">',
#   'nid': '294480',
#   'rank_display': '59',
#   'region': 'Europe',
#   'score': '74',
#   'stars': None,
#   'title': 'Ecole Polytechnique',
#   'url': '/universities/ecole-polytechnique'},
#  {'cc': 'AU',
#   'core_id': '412',
#   'country': 'Australia',
#   'guide': '<a href="/where-to-study/oceania/australia/guide" class="guide-link" target="_blank">Australia</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/monash-university_412_small_0.jpg" alt="Monash University Logo">',
#   'nid': '294848',
#   'rank_display': '60',
#   'region': 'Oceania',
#   'score': '73.1',
#   'stars': None,
#   'title': 'Monash University',
#   'url': '/universities/monash-university'},
#  {'cc': 'US',
#   'core_id': '667',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-washington_592560cf2aeae70239af4d1e_small.jpg" alt="University of Washington Logo">',
#   'nid': '297194',
#   'rank_display': '61',
#   'region': 'North America',
#   'score': '72.9',
#   'stars': None,
#   'title': 'University of Washington',
#   'url': '/universities/university-washington'},
#  {'cc': 'CN',
#   'core_id': '556',
#   'country': 'China',
#   'guide': '<a href="/where-to-study/asia/china/guide" class="guide-link" target="_blank">China</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/shanghai-jiao-tong-university_556_small.jpg" alt="Shanghai Jiao Tong University Logo">',
#   'nid': '297378',
#   'rank_display': '62',
#   'region': 'Asia',
#   'score': '72.5',
#   'stars': None,
#   'title': 'Shanghai Jiao Tong University',
#   'url': '/universities/shanghai-jiao-tong-university'},
#  {'cc': 'JP',
#   'core_id': '472',
#   'country': 'Japan',
#   'guide': '<a href="/where-to-study/asia/japan/guide" class="guide-link" target="_blank">Japan</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/osaka-university_472_small.jpg" alt="Osaka University Logo">',
#   'nid': '297628',
#   'rank_display': '63',
#   'region': 'Asia',
#   'score': '72.1',
#   'stars': None,
#   'title': 'Osaka University',
#   'url': '/universities/osaka-university'},
#  {'cc': 'DE',
#   'core_id': '599',
#   'country': 'Germany',
#   'guide': '<a href="/where-to-study/europe/germany/guide" class="guide-link" target="_blank">Germany</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/technical-university-of-munich_599_small.jpg" alt="Technical University of Munich Logo">',
#   'nid': '297262',
#   'rank_display': '64',
#   'region': 'Europe',
#   'score': '72',
#   'stars': None,
#   'title': 'Technical University of Munich',
#   'url': '/universities/technical-university-munich'},
#  {'cc': 'GB',
#   'core_id': '231',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-glasgow_231_small.jpg" alt="University of Glasgow Logo">',
#   'nid': '294322',
#   'rank_display': '65',
#   'region': 'Europe',
#   'score': '71.6',
#   'stars': '6',
#   'title': 'University of Glasgow',
#   'url': '/universities/university-glasgow'},
#  {'cc': 'DE',
#   'core_id': '420',
#   'country': 'Germany',
#   'guide': '<a href="/where-to-study/europe/germany/guide" class="guide-link" target="_blank">Germany</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/ludwig-maximilians-universitt-mnchen_420_small_0.jpg" alt="Ludwig-Maximilians-Universität München Logo">',
#   'nid': '294840',
#   'rank_display': '66',
#   'region': 'Europe',
#   'score': '70.8',
#   'stars': None,
#   'title': 'Ludwig-Maximilians-Universität München',
#   'url': '/universities/ludwig-maximilians-universit%C3%A4t-m%C3%BCnchen'},
#  {'cc': 'US',
#   'core_id': '604',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-texas-at-austin_604_small.jpg" alt="University of Texas at Austin Logo">',
#   'nid': '297257',
#   'rank_display': '67',
#   'region': 'North America',
#   'score': '70.6',
#   'stars': None,
#   'title': 'University of Texas at Austin',
#   'url': '/universities/university-texas-austin'},
#  {'cc': 'DE',
#   'core_id': '259',
#   'country': 'Germany',
#   'guide': '<a href="/where-to-study/europe/germany/guide" class="guide-link" target="_blank">Germany</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/ruprecht-karls-universitaet-heidelberg_259_small.jpg" alt="Ruprecht-Karls-Universität Heidelberg Logo">',
#   'nid': '294265',
#   'rank_display': '68',
#   'region': 'Europe',
#   'score': '70.4',
#   'stars': None,
#   'title': 'Ruprecht-Karls-Universität Heidelberg',
#   'url': '/universities/ruprecht-karls-universit%C3%A4t-heidelberg'},
#  {'cc': 'US',
#   'core_id': '2090',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-illinois-at-urbana-champaign_2090_small_0.jpg" alt="University of Illinois at Urbana-Champaign Logo">',
#   'nid': '295060',
#   'rank_display': '69',
#   'region': 'North America',
#   'score': '70.3',
#   'stars': None,
#   'title': 'University of Illinois at Urbana-Champaign',
#   'url': '/universities/university-illinois-urbana-champaign'},
#  {'cc': 'US',
#   'core_id': '225',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/georgia-institute-of-technology_225_small.jpg" alt="Georgia Institute of Technology Logo">',
#   'nid': '294349',
#   'rank_display': '70',
#   'region': 'North America',
#   'score': '70.1',
#   'stars': None,
#   'title': 'Georgia Institute of Technology',
#   'url': '/universities/georgia-institute-technology'},
#  {'cc': 'KR',
#   'core_id': '502',
#   'country': 'South Korea',
#   'guide': '<a href="/where-to-study/asia/south-korea/guide" class="guide-link" target="_blank">South Korea</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/pohang-university-of-science-and-technology-postech_502_small.jpg" alt="Pohang University of Science And Technology (POSTECH) Logo">',
#   'nid': '297501',
#   'rank_display': '=71',
#   'region': 'Asia',
#   'score': '69.4',
#   'stars': None,
#   'title': 'Pohang University of Science And Technology (POSTECH)',
#   'url': '/universities/pohang-university-science-technology-postech'},
#  {'cc': 'BE',
#   'core_id': '105',
#   'country': 'Belgium',
#   'guide': '<a href="/where-to-study/europe/belgium/guide" class="guide-link" target="_blank">Belgium</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/ku-leuven_105_small.jpg" alt="KU Leuven Logo">',
#   'nid': '294551',
#   'rank_display': '=71',
#   'region': 'Europe',
#   'score': '69.4',
#   'stars': None,
#   'title': 'KU Leuven',
#   'url': '/universities/ku-leuven'},
#  {'cc': 'DK',
#   'core_id': '141',
#   'country': 'Denmark',
#   'guide': '<a href="/where-to-study/europe/denmark/guide" class="guide-link" target="_blank">Denmark</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-copenhagen_141_small.jpg" alt="University of Copenhagen Logo">',
#   'nid': '294516',
#   'rank_display': '=73',
#   'region': 'Europe',
#   'score': '69.2',
#   'stars': None,
#   'title': 'University of Copenhagen',
#   'url': '/universities/university-copenhagen'},
#  {'cc': 'CH',
#   'core_id': '693',
#   'country': 'Switzerland',
#   'guide': '<a href="/where-to-study/europe/switzerland/guide" class="guide-link" target="_blank">Switzerland</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-zurich_693_small.jpg" alt="University of Zurich Logo">',
#   'nid': '297126',
#   'rank_display': '=73',
#   'region': 'Europe',
#   'score': '69.2',
#   'stars': None,
#   'title': 'University of Zurich',
#   'url': '/universities/university-zurich'},
#  {'cc': 'AR',
#   'core_id': '78',
#   'country': 'Argentina',
#   'guide': '<a href="/where-to-study/latin-america/argentina/guide" class="guide-link" target="_blank">Argentina</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/universidad-de-buenos-aires-uba_78_small.jpg" alt="Universidad de Buenos Aires (UBA) Logo">',
#   'nid': '294578',
#   'rank_display': '75',
#   'region': 'Latin America',
#   'score': '69.1',
#   'stars': None,
#   'title': 'Universidad de Buenos Aires (UBA)',
#   'url': '/universities/universidad-de-buenos-aires-uba'},
#  {'cc': 'JP',
#   'core_id': '611',
#   'country': 'Japan',
#   'guide': '<a href="/where-to-study/asia/japan/guide" class="guide-link" target="_blank">Japan</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/tohoku-university_611_small_0.jpg" alt="Tohoku University Logo">',
#   'nid': '297250',
#   'rank_display': '=76',
#   'region': 'Asia',
#   'score': '69',
#   'stars': None,
#   'title': 'Tohoku University',
#   'url': '/universities/tohoku-university'},
#  {'cc': 'TW',
#   'core_id': '441',
#   'country': 'Taiwan',
#   'guide': '<a href="/where-to-study/asia/taiwan/guide" class="guide-link" target="_blank">Taiwan</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/national-taiwan-university-ntu_441_small.jpg" alt="National Taiwan University (NTU) Logo">',
#   'nid': '294804',
#   'rank_display': '=76',
#   'region': 'Asia',
#   'score': '69',
#   'stars': None,
#   'title': 'National Taiwan University (NTU)',
#   'url': '/universities/national-taiwan-university-ntu'},
#  {'cc': 'GB',
#   'core_id': '170',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/durham-university_170_small.jpg" alt="Durham University Logo">',
#   'nid': '294488',
#   'rank_display': '=78',
#   'region': 'Europe',
#   'score': '68.5',
#   'stars': None,
#   'title': 'Durham University',
#   'url': '/universities/durham-university'},
#  {'cc': 'SE',
#   'core_id': '371',
#   'country': 'Sweden',
#   'guide': '<a href="/where-to-study/europe/sweden/guide" class="guide-link" target="_blank">Sweden</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/lund-university_371_small_1.jpg" alt="Lund University Logo">',
#   'nid': '293996',
#   'rank_display': '=78',
#   'region': 'Europe',
#   'score': '68.5',
#   'stars': '5',
#   'title': 'Lund University',
#   'url': '/universities/lund-university'},
#  {'cc': 'US',
#   'core_id': '424',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-north-carolina-chapel-hill_424_small.jpg" alt="University of North Carolina, Chapel Hill Logo">',
#   'nid': '294836',
#   'rank_display': '80',
#   'region': 'North America',
#   'score': '67.8',
#   'stars': None,
#   'title': 'University of North Carolina, Chapel Hill',
#   'url': '/universities/university-north-carolina-chapel-hill'},
#  {'cc': 'US',
#   'core_id': '63',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/boston-university_63_small.jpg" alt="Boston University Logo">',
#   'nid': '294593',
#   'rank_display': '81',
#   'region': 'North America',
#   'score': '67.2',
#   'stars': '5',
#   'title': 'Boston University',
#   'url': '/universities/boston-university'},
#  {'cc': 'NZ',
#   'core_id': '37',
#   'country': 'New Zealand',
#   'guide': '<a href="/where-to-study/oceania/new-zealand/guide" class="guide-link" target="_blank">New Zealand</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-auckland_37_small_0.jpg" alt="The University of Auckland Logo">',
#   'nid': '294619',
#   'rank_display': '=82',
#   'region': 'Oceania',
#   'score': '67',
#   'stars': '6',
#   'title': 'The University of Auckland',
#   'url': '/universities/university-auckland'},
#  {'cc': 'GB',
#   'core_id': '558',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-sheffield_558_small.jpg" alt="The University of Sheffield Logo">',
#   'nid': '297471',
#   'rank_display': '=82',
#   'region': 'Europe',
#   'score': '67',
#   'stars': None,
#   'title': 'The University of Sheffield',
#   'url': '/universities/university-sheffield'},
#  {'cc': 'GB',
#   'core_id': '59',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-birmingham_59_small_0.jpg" alt="University of Birmingham Logo">',
#   'nid': '294597',
#   'rank_display': '=84',
#   'region': 'Europe',
#   'score': '66.8',
#   'stars': None,
#   'title': 'University of Birmingham',
#   'url': '/universities/university-birmingham'},
#  {'cc': 'GB',
#   'core_id': '459',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-nottingham_459_small.jpg" alt="The University of Nottingham Logo">',
#   'nid': '294758',
#   'rank_display': '=84',
#   'region': 'Europe',
#   'score': '66.8',
#   'stars': None,
#   'title': 'The University of Nottingham',
#   'url': '/universities/university-nottingham'},
#  {'cc': 'US',
#   'core_id': '465',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-ohio-state-university_465_small.jpg" alt="The Ohio State University Logo">',
#   'nid': '294741',
#   'rank_display': '86',
#   'region': 'North America',
#   'score': '66.1',
#   'stars': '6',
#   'title': 'The Ohio State University',
#   'url': '/universities/ohio-state-university'},
#  {'cc': 'CN',
#   'core_id': '692',
#   'country': 'China',
#   'guide': '<a href="/where-to-study/asia/china/guide" class="guide-link" target="_blank">China</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/zhejiang-university_692_small.jpg" alt="Zhejiang University Logo">',
#   'nid': '297123',
#   'rank_display': '87',
#   'region': 'Asia',
#   'score': '65.9',
#   'stars': None,
#   'title': 'Zhejiang University',
#   'url': '/universities/zhejiang-university'},
#  {'cc': 'IE',
#   'core_id': '167',
#   'country': 'Ireland',
#   'guide': '<a href="/where-to-study/europe/ireland/guide" class="guide-link" target="_blank">Ireland</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/trinity-college-dublin-the-university-of-dublin_167_small_0.jpg" alt="Trinity College Dublin, The University of Dublin Logo">',
#   'nid': '294491',
#   'rank_display': '88',
#   'region': 'Europe',
#   'score': '65.7',
#   'stars': None,
#   'title': 'Trinity College Dublin, The University of Dublin',
#   'url': '/universities/trinity-college-dublin-university-dublin'},
#  {'cc': 'US',
#   'core_id': '524',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/rice-university_524_small.jpg" alt="Rice University Logo">',
#   'nid': '297437',
#   'rank_display': '89',
#   'region': 'North America',
#   'score': '65.6',
#   'stars': None,
#   'title': 'Rice University',
#   'url': '/universities/rice-university'},
#  {'cc': 'KR',
#   'core_id': '325',
#   'country': 'South Korea',
#   'guide': '<a href="/where-to-study/asia/south-korea/guide" class="guide-link" target="_blank">South Korea</a>',
# ...
#  {'cc': 'RS',
#   'core_id': '2243',
#   'country': 'Serbia',
#   'guide': '',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-belgrade_2243_small.jpg" alt="University of Belgrade Logo">',
#   'nid': '295204',
#   'rank_display': '801-1000',
#   'region': 'Europe',
#   'score': '',
#   'stars': None,
#   'title': 'University of Belgrade',
#   'url': '/universities/university-belgrade'},
#  {'cc': 'ID',
#   'core_id': '761',
#   'country': 'Indonesia',
#   'guide': '<a href="/where-to-study/asia/indonesia/guide" class="guide-link" target="_blank">Indonesia</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-brawijaya_761_small.jpg" alt="University of Brawijaya  Logo">',
#   'nid': '297069',
#   'rank_display': '801-1000',
#   'region': 'Asia',
#   'score': '',
#   'stars': '3',
#   'title': 'University of Brawijaya',
#   'url': '/universities/university-brawijaya'},
#  {'cc': 'GB',
#   'core_id': '113',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-central-lancashire_113_small_0.jpg" alt="University of Central Lancashire Logo">',
#   'nid': '294543',
#   'rank_display': '801-1000',
#   'region': 'Europe',
#   'score': '',
#   'stars': '4',
#   'title': 'University of Central Lancashire',
#   'url': '/universities/university-central-lancashire'},
#  {'cc': 'GB',
#   'core_id': '708',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-east-london_708_small.jpg" alt="University of East London Logo">',
#   'nid': '297350',
#   'rank_display': '801-1000',
#   'region': 'Europe',
#   'score': '',
#   'stars': None,
#   'title': 'University of East London',
#   'url': '/universities/university-east-london'},
#  {'cc': 'PK',
#   'core_id': '767',
#   'country': 'Pakistan',
#   'guide': '<a href="/where-to-study/asia/pakistan/guide" class="guide-link" target="_blank">Pakistan</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-engineering-technology-uet-lahore_592560cf2aeae70239af4d82_small.jpg" alt="University of Engineering & Technology (UET) Lahore Logo">',
#   'nid': '297063',
#   'rank_display': '801-1000',
#   'region': 'Asia',
#   'score': '',
#   'stars': None,
#   'title': 'University of Engineering & Technology (UET) Lahore',
#   'url': '/universities/university-engineering-technology-uet-lahore'},
#  {'cc': 'GH',
#   'core_id': '15046',
#   'country': 'Ghana',
#   'guide': '',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-ghana_15046_small.jpg" alt="University of Ghana Logo">',
#   'nid': '294208',
#   'rank_display': '801-1000',
#   'region': 'Africa',
#   'score': '',
#   'stars': None,
#   'title': 'University of Ghana',
#   'url': '/universities/university-ghana'},
#  {'cc': 'GB',
#   'core_id': '1645',
#   'country': 'United Kingdom',
#   'guide': '<a href="/where-to-study/europe/united-kingdom/guide" class="guide-link" target="_blank">United Kingdom</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-greenwich_592560cf2aeae70239af50f0_small.jpg" alt="University of Greenwich Logo">',
#   'nid': '296381',
#   'rank_display': '801-1000',
#   'region': 'Europe',
#   'score': '',
#   'stars': None,
#   'title': 'University of Greenwich',
#   'url': '/universities/university-greenwich'},
#  {'cc': 'PK',
#   'core_id': '701',
#   'country': 'Pakistan',
#   'guide': '<a href="/where-to-study/asia/pakistan/guide" class="guide-link" target="_blank">Pakistan</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-karachi_592560cf2aeae70239af4d40_small.jpg" alt="University of Karachi Logo">',
#   'nid': '297411',
#   'rank_display': '801-1000',
#   'region': 'Asia',
#   'score': '',
#   'stars': None,
#   'title': 'University of Karachi',
#   'url': '/universities/university-karachi'},
#  {'cc': 'PK',
#   'core_id': '334',
#   'country': 'Pakistan',
#   'guide': '<a href="/where-to-study/asia/pakistan/guide" class="guide-link" target="_blank">Pakistan</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/the-university-of-lahore_592560cf2aeae70239af4bda_small.jpg" alt="The University of Lahore Logo">',
#   'nid': '294092',
#   'rank_display': '801-1000',
#   'region': 'Asia',
#   'score': '',
#   'stars': None,
#   'title': 'The University of Lahore',
#   'url': '/universities/university-lahore'},
#  {'cc': 'SI',
#   'core_id': '1560',
#   'country': 'Slovenia',
#   'guide': '',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-maribor_592560cf2aeae70239af509c_small.jpg" alt="University of Maribor Logo">',
#   'nid': '297348',
#   'rank_display': '801-1000',
#   'region': 'Europe',
#   'score': '',
#   'stars': None,
#   'title': 'University of Maribor',
#   'url': '/universities/university-maribor'},
#  {'cc': 'US',
#   'core_id': '2284',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-mississippi_592560cf2aeae70239af536f_small.jpg" alt="University of Mississippi Logo">',
#   'nid': '295244',
#   'rank_display': '801-1000',
#   'region': 'North America',
#   'score': '',
#   'stars': None,
#   'title': 'University of Mississippi',
#   'url': '/universities/university-mississippi'},
#  {'cc': 'US',
#   'core_id': '2260',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-montana-missoula_2260_small.jpg" alt="University of Montana Missoula  Logo">',
#   'nid': '295221',
#   'rank_display': '801-1000',
#   'region': 'North America',
#   'score': '',
#   'stars': None,
#   'title': 'University of Montana Missoula',
#   'url': '/universities/university-montana-missoula'},
#  {'cc': 'IN',
#   'core_id': '419',
#   'country': 'India',
#   'guide': '<a href="/where-to-study/asia/india/guide" class="guide-link" target="_blank">India</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-mumbai_592560cf2aeae70239af4c26_small.jpg" alt="University of Mumbai Logo">',
#   'nid': '294841',
#   'rank_display': '801-1000',
#   'region': 'Asia',
#   'score': '',
#   'stars': None,
#   'title': 'University of Mumbai',
#   'url': '/universities/university-mumbai'},
#  {'cc': 'KE',
#   'core_id': '15043',
#   'country': 'Kenya',
#   'guide': '',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-nairobi_15043_small.jpg" alt="University of Nairobi Logo">',
#   'nid': '294204',
#   'rank_display': '801-1000',
#   'region': 'Africa',
#   'score': '',
#   'stars': None,
#   'title': 'University of Nairobi',
#   'url': '/universities/university-nairobi'},
#  {'cc': 'AU',
#   'core_id': '845',
#   'country': 'Australia',
#   'guide': '<a href="/where-to-study/oceania/australia/guide" class="guide-link" target="_blank">Australia</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-new-england-australia_845_small_0.jpg" alt="University of New England Australia Logo">',
#   'nid': '297044',
#   'rank_display': '801-1000',
#   'region': 'Oceania',
#   'score': '',
#   'stars': None,
#   'title': 'University of New England Australia',
#   'url': '/universities/university-new-england-australia'},
#  {'cc': 'IN',
#   'core_id': '509',
#   'country': 'India',
#   'guide': '<a href="/where-to-study/asia/india/guide" class="guide-link" target="_blank">India</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-pune_592560cf2aeae70239af4c80_small.jpg" alt="Savitribai Phule Pune University Logo">',
#   'nid': '297488',
#   'rank_display': '801-1000',
#   'region': 'Asia',
#   'score': '',
#   'stars': None,
#   'title': 'Savitribai Phule Pune University',
#   'url': '/universities/savitribai-phule-pune-university'},
#  {'cc': 'US',
#   'core_id': '546',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-san-diego_592560cf2aeae70239af4ca6_small.jpg" alt="University of San Diego Logo">',
#   'nid': '297472',
#   'rank_display': '801-1000',
#   'region': 'North America',
#   'score': '',
#   'stars': None,
#   'title': 'University of San Diego',
#   'url': '/universities/university-san-diego'},
#  {'cc': 'US',
#   'core_id': '711',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-san-francisco_592560cf2aeae70239af4d4a_small.jpg" alt="University of San Francisco Logo">',
#   'nid': '297118',
#   'rank_display': '801-1000',
#   'region': 'North America',
#   'score': '',
#   'stars': None,
#   'title': 'University of San Francisco',
#   'url': '/universities/university-san-francisco'},
#  {'cc': 'PH',
#   'core_id': '549',
#   'country': 'Philippines',
#   'guide': '<a href="/where-to-study/asia/philippines/guide" class="guide-link" target="_blank">Philippines</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-santo-tomas_592560cf2aeae70239af4ca8_small.jpg" alt="University of Santo Tomas Logo">',
#   'nid': '297425',
#   'rank_display': '801-1000',
#   'region': 'Asia',
#   'score': '',
#   'stars': '4',
#   'title': 'University of Santo Tomas',
#   'url': '/universities/university-santo-tomas'},
#  {'cc': 'US',
#   'core_id': '479',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-the-pacific_592560cf2aeae70239af4c6b_small.jpg" alt="University of the Pacific Logo">',
#   'nid': '297586',
#   'rank_display': '801-1000',
#   'region': 'North America',
#   'score': '',
#   'stars': None,
#   'title': 'University of the Pacific',
#   'url': '/universities/university-pacific'},
#  {'cc': 'AU',
#   'core_id': '847',
#   'country': 'Australia',
#   'guide': '<a href="/where-to-study/oceania/australia/guide" class="guide-link" target="_blank">Australia</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-the-sunshine-coast_847_small.jpg" alt="University of the Sunshine Coast  Logo">',
#   'nid': '297042',
#   'rank_display': '801-1000',
#   'region': 'Oceania',
#   'score': '',
#   'stars': None,
#   'title': 'University of the Sunshine Coast',
#   'url': '/universities/university-sunshine-coast'},
#  {'cc': 'ZA',
#   'core_id': '1216',
#   'country': 'South Africa',
#   'guide': '<a href="/where-to-study/africa/south-africa/guide" class="guide-link" target="_blank">South Africa</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-the-western-cape_592560cf2aeae70239af4f56_small.jpg" alt="University of the Western Cape Logo">',
#   'nid': '297598',
#   'rank_display': '801-1000',
#   'region': 'Africa',
#   'score': '',
#   'stars': None,
#   'title': 'University of the Western Cape',
#   'url': '/universities/university-western-cape'},
#  {'cc': 'PL',
#   'core_id': '1465',
#   'country': 'Poland',
#   'guide': '<a href="/where-to-study/europe/poland/guide" class="guide-link" target="_blank">Poland</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/university-of-wroclaw_1465_small.jpg" alt="University of Wroclaw Logo">',
#   'nid': '296500',
#   'rank_display': '801-1000',
#   'region': 'Europe',
#   'score': '',
#   'stars': None,
#   'title': 'University of Wroclaw',
#   'url': '/universities/university-wroclaw'},
#  {'cc': 'FR',
#   'core_id': '621',
#   'country': 'France',
#   'guide': '<a href="/where-to-study/europe/france/guide" class="guide-link" target="_blank">France</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/universit-de-toulouse-ii-le-mirail_621_small.jpg" alt="Université de Toulouse II-Le Mirail Logo">',
#   'nid': '297240',
#   'rank_display': '801-1000',
#   'region': 'Europe',
#   'score': '',
#   'stars': None,
#   'title': 'Université de Toulouse II-Le Mirail',
#   'url': '/universities/universit%C3%A9-de-toulouse-ii-le-mirail'},
#  {'cc': 'US',
#   'core_id': '1864',
#   'country': 'United States',
#   'guide': '<a href="/where-to-study/north-america/united-states/guide" class="guide-link" target="_blank">United States</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/utah-state-university-_592560cf2aeae70239af51cb_small.jpg" alt="Utah State University Logo">',
#   'nid': '294763',
#   'rank_display': '801-1000',
#   'region': 'North America',
#   'score': '',
#   'stars': None,
#   'title': 'Utah State University',
#   'url': '/universities/utah-state-university'},
#  {'cc': 'IT',
#   'core_id': '14329',
#   'country': 'Italy',
#   'guide': '<a href="/where-to-study/europe/italy/guide" class="guide-link" target="_blank">Italy</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/verona-university_14329_small.jpg" alt="Verona University Logo">',
#   'nid': '293776',
#   'rank_display': '801-1000',
#   'region': 'Europe',
#   'score': '',
#   'stars': None,
#   'title': 'Verona University',
#   'url': '/universities/verona-university'},
#  {'cc': 'RU',
#   'core_id': '1499',
#   'country': 'Russia',
#   'guide': '<a href="/where-to-study/europe/russia/guide" class="guide-link" target="_blank">Russia</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/voronezh-state-university_1499_small_0.jpg" alt="Voronezh State University Logo">',
#   'nid': '296472',
#   'rank_display': '801-1000',
#   'region': 'Europe',
#   'score': '',
#   'stars': '3',
#   'title': 'Voronezh State University',
#   'url': '/universities/voronezh-state-university'},
#  {'cc': 'LT',
#   'core_id': '1455',
#   'country': 'Lithuania',
#   'guide': '<a href="/where-to-study/europe/lithuania/guide" class="guide-link" target="_blank">Lithuania</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/vytautas-magnus-university_592560cf2aeae70239af5032_small.jpg" alt="Vytautas Magnus University Logo">',
#   'nid': '296510',
#   'rank_display': '801-1000',
#   'region': 'Europe',
#   'score': '',
#   'stars': '2',
#   'title': 'Vytautas Magnus University',
#   'url': '/universities/vytautas-magnus-university'},
#  {'cc': 'RO',
#   'core_id': '1488',
#   'country': 'Romania',
#   'guide': '<a href="/where-to-study/europe/romania/guide" class="guide-link" target="_blank">Romania</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/universitatea-de-vest-din-timisoara-west-university-of-timisoara_592560cf2aeae70239af5054_small.jpg" alt="Universitatea de Vest din Timisoara /  West University of Timisoara Logo">',
#   'nid': '296481',
#   'rank_display': '801-1000',
#   'region': 'Europe',
#   'score': '',
#   'stars': None,
#   'title': 'Universitatea de Vest din Timisoara /  West University of Timisoara',
#   'url': '/universities/universitatea-de-vest-din-timisoara-west-university-timisoara'},
#  {'cc': 'PL',
#   'core_id': '1462',
#   'country': 'Poland',
#   'guide': '<a href="/where-to-study/europe/poland/guide" class="guide-link" target="_blank">Poland</a>',
#   'logo': '<img src="https://www.topuniversities.com/sites/default/files/wroclaw-university-of-technology_592560cf2aeae70239af5039_small.jpg" alt="Wroclaw University of Technology Logo">',
#   'nid': '296503',
#   'rank_display': '801-1000',
#   'region': 'Europe',
#   'score': '',
#   'stars': None,
#   'title': 'Wroclaw University of Technology',
#   'url': '/universities/wroclaw-university-technology'}]

# %% [markdown]
# We clean and arrange the data to support our analysis:

# %%
univ_list = []
for univ in newdf[0:200]:
    univ_crt = pd.DataFrame([]); 
    
    # Get simple information from in the main list
    name = univ['name'] 
    rank = univ['rank']
    country = univ['location']
    if country=='Russian Federation':
        country='Russia'
    
    num_student = int(univ['stats_number_students'].strip().replace(',',''))
    perc_int_student = float(univ['stats_pc_intl_students'].strip().replace('%',''))
    num_int_student = int(num_student * perc_int_student / 100) 
    
    ratio_stud_falc = float(univ['stats_student_staff_ratio'])
    num_faculty = int( (1 / ratio_stud_falc) *  num_student)
    
    # Get informations from details pages
#     details_r = requests.get( URL_times + univ['url'] )
#     page_body = details_r.text
#     soup = BeautifulSoup(page_body, 'html.parser')
       
    for univ2 in data2:
        if country==univ2['country']:
            region=univ2['region']
    
    univ_crt = {'Name': name, 
                'Rank times': rank,
                'Country': country,
                'Num students times': num_student,
                'Num intl students times': num_int_student,
                'Num faculty times': num_faculty,
                'Region':region
                } 
    
    univ_list.append(univ_crt)  

df_times_original = pd.DataFrame.from_dict(univ_list)
df_times= df_times_original.copy()
df_times_original.head()
# Out:
#           Country                                   Name  Num faculty times  \
# 0  United Kingdom                   University of Oxford               1822
# 1  United Kingdom                University of Cambridge               1687
# 2   United States     California Institute of Technology                339
# 3   United States                    Stanford University               2112
# 4   United States  Massachusetts Institute of Technology               1284
#
#    Num intl students times  Num students times Rank times         Region
# 0                     7755               20409          1         Europe
# 1                     6436               18389          2         Europe
# 2                      596                2209         =3  North America
# 3                     3485               15845         =3  North America
# 4                     3800               11177          5  North America

# %% [markdown]
# Now let's compute gain all the data that matter in our analysis by keeping only the relevant columns

# %%
df_times['stud intl/tot times'] = df_times['Num intl students times']/df_times['Num students times']

# %%
df_times['fac/tot times'] = df_times['Num faculty times']/df_times['Num students times']

# %%
df_times.head()
# Out:
#           Country                                   Name  Num faculty times  \
# 0  United Kingdom                   University of Oxford               1822
# 1  United Kingdom                University of Cambridge               1687
# 2   United States     California Institute of Technology                339
# 3   United States                    Stanford University               2112
# 4   United States  Massachusetts Institute of Technology               1284
#
#    Num intl students times  Num students times Rank times         Region  \
# 0                     7755               20409          1         Europe
# 1                     6436               18389          2         Europe
# 2                      596                2209         =3  North America
# 3                     3485               15845         =3  North America
# 4                     3800               11177          5  North America
#
#    stud intl/tot times  fac/tot times
# 0             0.379979       0.089274
# 1             0.349992       0.091740
# 2             0.269805       0.153463
# 3             0.219943       0.133291
# 4             0.339984       0.114879

# %% [markdown]
# Let's have a look to countries and region repartition

# %% [markdown]
# TO BE COMPLETED

# %%
df_times.sort_values(['stud intl/tot times'], ascending = 0, axis = 0).head()
# Out:
#             Country                                              Name  \
# 24   United Kingdom  London School of Economics and Political Science
# 178      Luxembourg                          University of Luxembourg
# 7    United Kingdom                           Imperial College London
# 37      Switzerland          École Polytechnique Fédérale de Lausanne
# 102     Netherlands                             Maastricht University
#
#      Num faculty times  Num intl students times  Num students times  \
# 24                 825                     7146               10065
# 178                340                     2832                4969
# 7                 1390                     8721               15857
# 37                 886                     5460                9928
# 102                929                     8363               16727
#
#     Rank times  Region  stud intl/tot times  fac/tot times
# 24         =25  Europe             0.709985       0.081967
# 178       =179    Asia             0.569934       0.068424
# 7            8  Europe             0.549978       0.087658
# 37         =38  Europe             0.549960       0.089243
# 102        103  Europe             0.499970       0.055539

# %% [markdown]
#
# ## 3. Merge the two DataFrames created in questions 1 and 2 using university names. Match universities' names as well as you can, and explain your strategy. Keep track of the original position in both rankings.

# %% [markdown]
# ##### Challenge
# The university name can differ between the 2 rankings. For example, in the Times ranking, we have "École Polytechnique Fédérale de Lausanne", which is named "Ecole Polytechnique Fédérale de Lausanne (EPFL)" in the topuniversity ranking.
#
#
# Moreover, a university can be ranked in the top 200 in one ranking and can also be over rank 200 in the other one.

# %% [markdown]
# ##### Our idea
#
#
# To find match between the names of the universities, we will use `difflib`, a python module that provides functions for comparing sequences. The one we are interested in is **`SequenceMatcher`**.
# This allows to compute a matching score between two strings.

# %%
from difflib import SequenceMatcher
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
# To start over with original dataframes
df_topu = df_original.copy()
df_times = df_times_original.copy()

# %% [markdown]
# ##### Our implementation
#
#
# For each university of the first dataframe, we check if its name matches with one in the other dataframe. We get only match with a matching score over a certain threshold score we define later.
# If a university matches several ones in the other dataframe, we choose the one with the highest score, and update its name,to have exactly the same in both dataframe.
# If a university doesn't match any in the other dataframe, we don't change anything.
#
# Finally we can merge on the university names.

# %%
threshold_score = 0.87

nb_match = 0
for index_topu, univ_topu in df_topu.iterrows():
    match = []
    
    for index_times, univ_times in df_times.iterrows():
        match_score = similar(univ_topu.title, univ_times.Name)
        if match_score > threshold_score:
            match.append({'match_name': univ_times.Name, 'score': match_score})
            
    if match:  # Check if the list is empty (in case there is no match)
        df_match = pd.DataFrame.from_dict(match)
        
#         if len(match) > 1:
#             print("\n :::: {}".format(univ_topu.Name))
#             print(df_match)
        
        highest_match = df_match.loc[df_match['score'].idxmax()]
        if highest_match['score'] < 0.92:
            print("{}: {} --- {}".format(highest_match['score'], df_topu.loc[index_topu,'title'], highest_match['match_name']))
        df_topu.loc[index_topu,'Name'] = highest_match['match_name']
        nb_match += 1
# Out:
# 0.8717948717948718: California Institute of Technology (Caltech) --- California Institute of Technology
# 0.8928571428571429: UCL (University College London) --- University College London
# 0.9158878504672897: ETH Zurich - Swiss Federal Institute of Technology --- ETH Zurich – Swiss Federal Institute of Technology Zurich
# 0.896551724137931: Ecole Polytechnique Fédérale de Lausanne (EPFL) --- École Polytechnique Fédérale de Lausanne
# 0.9142857142857143: National University of Singapore (NUS) --- National University of Singapore
# 0.918918918918919: University of California, Berkeley (UCB) --- University of California, Berkeley
# 0.9047619047619048: The University of Tokyo --- University of Tokyo
# 0.9135802469135802: University of California, Los Angeles (UCLA) --- University of California, Los Angeles
# 0.9090909090909091: University of California, San Diego (UCSD) --- University of California, San Diego
# 0.9090909090909091: The University of Sydney --- University of Sydney
# 0.8709677419354839: Tokyo Institute of Technology --- KTH Royal Institute of Technology
# 0.9130434782608695: The University of Warwick --- University of Warwick
# 0.875: Pohang University of Science And Technology (POSTECH) --- Pohang University of Science and Technology
# 0.896551724137931: National Taiwan University (NTU) --- National Taiwan University
# 0.9166666666666666: The University of Auckland --- University of Auckland
# 0.9130434782608695: The Ohio State University --- Ohio State University
# 0.9166666666666666: The University of Adelaide --- University of Adelaide
# 0.9176470588235294: University of California, Santa Barbara (UCSB) --- University of California, Santa Barbara
# 0.8857142857142857: Université catholique de Louvain (UCL) --- Université Catholique de Louvain
# 0.9090909090909091: The University of Exeter --- University of Exeter

# %% [markdown]
# ##### Choice of the threshold score
#
# We tested different threshold matching score and tried to affine it.
#
# At first, 0.85 looked good, but we found inconsistencies in our results. We check at matching universities for those with more than one match. We found the **Vienna University of Technology**, which is in the 200 top ranking universities only in topuniversities ranking and that is over the 300rank in the Times one. It had a the following  matching score :
#
#                             match_name     score
#         Delft University of Technology  0.852459
#     Eindhoven University of Technology  0.861538
#
#
# Obviously, none of the those two universities were the good one. Thus, we had to update our threshold score by increasing it to affine this kind of wrong match.
#
#
# We didn't increase it too much so that all the universities with a match can find it. For example it is sure that "The University of Hong Kong" should match with "University of Hong Kong". Their matching score is "only" 0.92 (see table below),so for cases like this, we can't put a threshold score too high.
#
#                             match_name     score
#     0          University of Hong Kong  0.920000
#     1  Chinese University of Hong Kong  0.896552
#     2     City University of Hong Kong  0.872727

# %%
print("-> {} match between university names were found in the two rankings".format(nb_match))
# Out:
# -> 145 match between university names were found in the two rankings

# %% [markdown]
# Now, let's merge our two dataframes

# %%
# Merge the 2 dataframe on university names
df_merged = pd.merge(df_topu, df_times, how='outer', right_on='Name', left_on='Name')
# df_merged

# %%
df_merged.head()
# Out:
#           country rank_display         region  \
# 0   United States            1  North America
# 1   United States            2  North America
# 2   United States            3  North America
# 3   United States            4  North America
# 4  United Kingdom            5         Europe
#
#                                           title  Nb Faculty QS  \
# 0   Massachusetts Institute of Technology (MIT)         2982.0
# 1                           Stanford University         4285.0
# 2                            Harvard University         4350.0
# 3  California Institute of Technology (Caltech)          953.0
# 4                       University of Cambridge         5490.0
#
#    Nb Faculty inter QS  Nb Students QS  Nb Students Inter QS  \
# 0               1679.0         11067.0                3717.0
# 1               2042.0         15878.0                3611.0
# 2               1311.0         22429.0                5266.0
# 3                350.0          2255.0                 647.0
# 4               2278.0         18770.0                6699.0
#
#    ratio Faculty/Students QS  ratio Inter Students/Students QS  \
# 0                   0.269450                          0.335863
# 1                   0.269870                          0.227422
# 2                   0.193945                          0.234785
# 3                   0.422616                          0.286918
# 4                   0.292488                          0.356899
#
#                                     Name         Country  Num faculty times  \
# 0  Massachusetts Institute of Technology   United States             1284.0
# 1                    Stanford University   United States             2112.0
# 2                     Harvard University   United States             2283.0
# 3     California Institute of Technology   United States              339.0
# 4                University of Cambridge  United Kingdom             1687.0
#
#    Num intl students times  Num students times Rank times         Region
# 0                   3800.0             11177.0          5  North America
# 1                   3485.0             15845.0         =3  North America
# 2                   5284.0             20326.0          6  North America
# 3                    596.0              2209.0         =3  North America
# 4                   6436.0             18389.0          2         Europe

# %%
import statsmodels.formula.api  as lm

# %% [markdown]
#  Bonus: (to be adapted with variables)

# %% [markdown]
# Let's confront the two rankings dataset on Oxford university

# %%
newdf=newdf.set_index('aliases')

# %%
newdf.loc['University of Oxford','stats_pc_intl_students']==df.set_index('title').loc['University of Oxford','ratio Inter Students/Students']

# %%
newdf.loc['University of Oxford','stats_pc_intl_students']#times

# %%
df.set_index('title').loc['University of Oxford','ratio Inter Students/Students']#QS

# %% [markdown]
# Data are close but not exactly the same. What a surprise, the times inflates score of an english university...Let's check with Cambrige university.

# %%
newdf.loc['University of Cambridge','stats_pc_intl_students']==df.set_index('title').loc['University of Cambridge','ratio Inter Students/Students']

# %%
newdf.loc['University of Cambridge','stats_pc_intl_students']#times

# %%
df.set_index('title').loc['University of Cambridge','ratio Inter Students/Students']#QS

# %% [markdown]
# Ok my bad...Hmmm I want to be sure, I'll check on all england univ

# %%
newdf.set_index('location').loc['United Kingdom',:]#times

# %%
df.set_index('country').loc['United Kingdom',:]#QS

# %% [markdown]
# With a quick eye check, we notice that many THE data for international student ratios are inflated compared to QS.
